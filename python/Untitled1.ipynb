# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import pickle
import csv
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
#vine linux
f = pd.read_csv('/home/hera/nodoka/home2/nodoka/spike-data/25kHz-data/B36 Rd.csv',header=None)
f.to_pickle('/home/hera/nodoka/home2/nodoka/spike-data/25kHz-data/B36 Rd.pickle')

#mac
#f = pd.read_csv('/Volumes/NO NAME/25kHz-data/B36 Rd.csv',header=None)
#f.to_pickle('/Volumes/NO NAME/25kHz-data/B36 Rd.pickle')

#ubuntu
#f = pd.read_csv('/home/hera/nodoka/home2/nodoka/spike-data/25kHz-data/B36 Rd.csv',header=None)
#f.to_pickle('/home/nodoka/spike-data/25kHz-data/B36 Rd.pickle')

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import pickle
import csv
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
#vine linux
#f = pd.read_csv('/home/hera/nodoka/home2/nodoka/spike-data/25kHz-data/B39 Rd.csv',header=None)
#f.to_pickle('/home/hera/nodoka/home2/nodoka/spike-data/25kHz-data/B39 Rd.pickle')

#mac
f = pd.read_csv('/Volumes/NO NAME/25kHz-data/B39 Rd.csv',header=None)
f.to_pickle('/Volumes/NO NAME/25kHz-data/B39 Rd.pickle')

#ubuntu
#f = pd.read_csv('/home/hera/nodoka/home2/nodoka/spike-data/25kHz-data/B39 Rd.csv',header=None)
#f.to_pickle('/home/nodoka/spike-data/25kHz-data/B39 Rd.pickle')

# %%
import pickle
import numpy as np
import wave
from pylab import *
with open('/home/hera/nodoka/home2/nodoka/spike-data/25kHz-data/B36 Rd.pickle', mode='rb') as fp:
#with open('/home/hera/nodoka/home2/nodoka/spike-data/25kHz-data/B36 Rd.pickle', mode='rb') as fp:
#with open('/Volumes/NO NAME/25kHz-data/B36 Rd.pickle',mode='rb') as fp:
    df = pickle.load(fp)

#start = int(58.59/0.00004)
#end = int(197.47/0.00004)
#start = int(167.39/0.00004)
#end = int(272.67/0.00004)
#start = int(881.13744/0.00004)
#end = int(881.35202/0.00004)

starttime = 881.13744
endtime = 881.35202
start = int(starttime/0.00004)
end = int(endtime/0.00004)
datatime = []
#print(df[start:end])
#specdatab = np.array(df[start:end])
for i in range(len(df[start:end])):
#    print(i)
    datatime.append([(starttime+(i*0.00004))])
#print(datatime)

plt.subplot(2, 2, 1)
plt.plot(datatime,df[start:end])
del datatime

#data = df.dataframe([0], dtype='float')
#data = (pd.Series(df[start:end], dtype=np.float64))
#data = df.as_matrix(0,)#[start:end]
specdatab = np.array(df[start:end])
specdataa = specdatab.flatten()
fp.close
#print(specdataa)
N = 1024
hammingWindow = np.hamming(N)
samplingrate = 25000
length = (end - start)/samplingrate

# FFTで用いるハミング窓
hammingWindow = np.hamming(N)

# スペクトログラムを描画
plt.subplot(2, 2, 2)
pxx, freqs, bins, im = plt.specgram(specdataa, NFFT=N, Fs=samplingrate, noverlap=0, window=hammingWindow)
axis([0, length, 0, samplingrate / 2])
xlabel("time [second]")
plt.ylim([0,2056])
ylabel("frequency [Hz]")
plt.colorbar()



plt.subplot(2, 2, 3)
starttime = 889.13744
endtime = 889.35202
datatime = []
start = int(starttime/0.00004)
end = int(endtime/0.00004)
for i in range(len(df[start:end])):
    datatime.append([(starttime+(i*0.00004))])
plt.plot(datatime,df[start:end])

#data = df.dataframe([0], dtype='float')
#data = (pd.Series(df[start:end], dtype=np.float64))
#data = df.as_matrix(0,)#[start:end]
specdatab = np.array(df[start:end])
specdataa = specdatab.flatten()
fp.close
#print(specdataa)
N = 1024
hammingWindow = np.hamming(N)
samplingrate = 25000
length = (end - start)/samplingrate

# FFTで用いるハミング窓
hammingWindow = np.hamming(N)

# スペクトログラムを描画
plt.subplot(2, 2, 4)
pxx, freqs, bins, im = plt.specgram(specdataa, NFFT=N, Fs=samplingrate, noverlap=0, window=hammingWindow)
axis([0, length, 0, samplingrate / 2])
xlabel("time [second]")
plt.ylim([0,2056])
ylabel("frequency [Hz]")
plt.colorbar()



show()
del df, specdataa, specdatab, pxx, freqs, bins, im

# %%
import pickle
import numpy as np
import wave
from pylab import *
#with open('/home/hera/nodoka/home2/nodoka/spike-data/25kHz-data/B36 Rd.pickle', mode='rb') as fp:
#with open('/home/hera/nodoka/home2/nodoka/spike-data/25kHz-data/B36 Rd.pickle', mode='rb') as fp:
with open('/Volumes/NO NAME/25kHz-data/B36 Rd.pickle',mode='rb') as fp:
    df = pickle.load(fp)
    
####base---------------------------------------------------------------------------------------------
starttime = 400
endtime = 800
start = int(starttime/0.00004)
end = int(endtime/0.00004)
datatime = []
#print(df[start:end])
#specdatab = np.array(df[start:end])
for i in range(len(df[start:end])):
#    print(i)
    datatime.append([(starttime+(i*0.00004))])
#print(datatime)

plt.subplot(3, 2, 1)
plt.plot(datatime,df[start:end])
del datatime

#data = df.dataframe([0], dtype='float')
#data = (pd.Series(df[start:end], dtype=np.float64))
#data = df.as_matrix(0,)#[start:end]
specdatab = np.array(df[start:end])
specdataa = specdatab.flatten()
fp.close
#print(specdataa)
N = 2^(14)
hammingWindow = np.hamming(N)
samplingrate = 25000
length = (end - start)/samplingrate

# FFTで用いるハミング窓
hammingWindow = np.hamming(N)

# スペクトログラムを描画
plt.subplot(3, 2, 2)
pxx, freqs, bins, im = plt.specgram(specdataa, NFFT=N, Fs=samplingrate, noverlap=0, window=hammingWindow)
axis([0, length, 0, samplingrate / 2])
xlabel("time [second]")
#plt.ylim(0,4096)
ylabel("frequency [Hz]")
plt.colorbar()


####10min---------------------------------------------------------------------------------------------
starttime = 1600
endtime = 2000
start = int(starttime/0.00004)
end = int(endtime/0.00004)
datatime = []
#print(df[start:end])
#specdatab = np.array(df[start:end])
for i in range(len(df[start:end])):
#    print(i)
    datatime.append([(starttime+(i*0.00004))])
#print(datatime)

plt.subplot(3, 2, 3)
plt.plot(datatime,df[start:end])
del datatime

#data = df.dataframe([0], dtype='float')
#data = (pd.Series(df[start:end], dtype=np.float64))
#data = df.as_matrix(0,)#[start:end]
specdatab = np.array(df[start:end])
specdataa = specdatab.flatten()
fp.close
#print(specdataa)
N = 2^(14)
hammingWindow = np.hamming(N)
samplingrate = 25000
length = (end - start)/samplingrate

# FFTで用いるハミング窓
hammingWindow = np.hamming(N)

# スペクトログラムを描画
plt.subplot(3, 2, 4)
pxx, freqs, bins, im = plt.specgram(specdataa, NFFT=N, Fs=samplingrate, noverlap=0, window=hammingWindow)
axis([0, length, 0, samplingrate / 2])
xlabel("time [second]")
#plt.ylim(0,4096)
ylabel("frequency [Hz]")
plt.colorbar()



####10min---------------------------------------------------------------------------------------------
starttime = 2800
endtime = 3200
start = int(starttime/0.00004)
end = int(endtime/0.00004)
datatime = []
#print(df[start:end])
#specdatab = np.array(df[start:end])
for i in range(len(df[start:end])):
#    print(i)
    datatime.append([(starttime+(i*0.00004))])
#print(datatime)

plt.subplot(3, 2, 5)
plt.plot(datatime,df[start:end])
del datatime

#data = df.dataframe([0], dtype='float')
#data = (pd.Series(df[start:end], dtype=np.float64))
#data = df.as_matrix(0,)#[start:end]
specdatab = np.array(df[start:end])
specdataa = specdatab.flatten()
fp.close
#print(specdataa)
N = 2^(14)
hammingWindow = np.hamming(N)
samplingrate = 25000
length = (end - start)/samplingrate

# FFTで用いるハミング窓
hammingWindow = np.hamming(N)

# スペクトログラムを描画
plt.subplot(3, 2, 6)
pxx, freqs, bins, im = plt.specgram(specdataa, NFFT=N, Fs=samplingrate, noverlap=0, window=hammingWindow)
axis([0, length, 0, samplingrate / 2])
xlabel("time [second]")
#plt.ylim(0,4096)
ylabel("frequency [Hz]")
plt.colorbar()

show()

del df, specdataa, specdatab, pxx, freqs, bins, im

# %%
import pickle
import numpy as np
import wave
#import matplotlib as mpl
#mpl.rcParams['agg.path.chunksize'] = 100000
from pylab import *
#with open('/home/hera/nodoka/home2/nodoka/spike-data/25kHz-data/B39 Rd.pickle', mode='rb') as fp:
#with open('/home/hera/nodoka/home2/nodoka/spike-data/25kHz-data/B39 Rd.pickle', mode='rb') as fp:
with open('/Volumes/NO NAME/25kHz-data/B39 Rd.pickle',mode='rb') as fp:
    df = pickle.load(fp)
    
####base---------------------------------------------------------------------------------------------
starttime = 400
endtime = 800
start = int(starttime/0.00004)
end = int(endtime/0.00004)
datatime = []
#print(df[start:end])
#specdatab = np.array(df[start:end])
for i in range(len(df[start:end])):
#    print(i)
    datatime.append([(starttime+(i*0.00004))])
#print(datatime)

plt.subplot(3, 2, 1)
plt.plot(datatime,df[start:end])
del datatime

#data = df.dataframe([0], dtype='float')
#data = (pd.Series(df[start:end], dtype=np.float64))
#data = df.as_matrix(0,)#[start:end]
specdatab = np.array(df[start:end])
specdataa = specdatab.flatten()
fp.close
#print(specdataa)
N = 2^(14)
hammingWindow = np.hamming(N)
samplingrate = 25000
length = (end - start)/samplingrate

# FFTで用いるハミング窓
hammingWindow = np.hamming(N)

# スペクトログラムを描画
plt.subplot(3, 2, 2)
pxx, freqs, bins, im = plt.specgram(specdataa, NFFT=N, Fs=samplingrate, noverlap=0, window=hammingWindow)
axis([0, length, 0, samplingrate / 2])
xlabel("time [second]")
#plt.ylim(0,4096)
ylabel("frequency [Hz]")
plt.colorbar()


####10min---------------------------------------------------------------------------------------------
starttime = 1600
endtime = 2000
start = int(starttime/0.00004)
end = int(endtime/0.00004)
datatime = []
#print(df[start:end])
#specdatab = np.array(df[start:end])
for i in range(len(df[start:end])):
#    print(i)
    datatime.append([(starttime+(i*0.00004))])
#print(datatime)

plt.subplot(3, 2, 3)
plt.plot(datatime,df[start:end])
del datatime

#data = df.dataframe([0], dtype='float')
#data = (pd.Series(df[start:end], dtype=np.float64))
#data = df.as_matrix(0,)#[start:end]
specdatab = np.array(df[start:end])
specdataa = specdatab.flatten()
fp.close
#print(specdataa)
N = 2^(14)
hammingWindow = np.hamming(N)
samplingrate = 25000
length = (end - start)/samplingrate

# FFTで用いるハミング窓
hammingWindow = np.hamming(N)

# スペクトログラムを描画
plt.subplot(3, 2, 4)
pxx, freqs, bins, im = plt.specgram(specdataa, NFFT=N, Fs=samplingrate, noverlap=0, window=hammingWindow)
axis([0, length, 0, samplingrate / 2])
xlabel("time [second]")
#plt.ylim(0,4096)
ylabel("frequency [Hz]")
plt.colorbar()



####10min---------------------------------------------------------------------------------------------
starttime = 2750
endtime = 3150
start = int(starttime/0.00004)
end = int(endtime/0.00004)
datatime = []
#print(df[start:end])
#specdatab = np.array(df[start:end])
for i in range(len(df[start:end])):
#    print(i)
    datatime.append([(starttime+(i*0.00004))])
#print(datatime)

plt.subplot(3, 2, 5)
plt.plot(datatime,df[start:end])
del datatime

#data = df.dataframe([0], dtype='float')
#data = (pd.Series(df[start:end], dtype=np.float64))
#data = df.as_matrix(0,)#[start:end]
specdatab = np.array(df[start:end])
specdataa = specdatab.flatten()
fp.close
#print(specdataa)
N = 2^(14)
hammingWindow = np.hamming(N)
samplingrate = 25000
length = (end - start)/samplingrate

# FFTで用いるハミング窓
hammingWindow = np.hamming(N)

# スペクトログラムを描画
plt.subplot(3, 2, 6)
pxx, freqs, bins, im = plt.specgram(specdataa, NFFT=N, Fs=samplingrate, noverlap=0, window=hammingWindow)
axis([0, length, 0, samplingrate / 2])
xlabel("time [second]")
#plt.ylim(0,4096)
ylabel("frequency [Hz]")
plt.colorbar()

show()

del df, specdataa, specdatab, pxx, freqs, bins, im
# Out:
# /Users/neko/.pyenv/versions/anaconda3-4.4.0/lib/python3.6/site-packages/matplotlib/transforms.py:2786: RuntimeWarning: overflow encountered in double_scalars
#   elif vmax - vmin <= maxabsvalue * tiny:
# /Users/neko/.pyenv/versions/anaconda3-4.4.0/lib/python3.6/site-packages/matplotlib/axes/_base.py:2322: RuntimeWarning: overflow encountered in double_scalars
#   delta = (x1t - x0t) * margin
# /Users/neko/.pyenv/versions/anaconda3-4.4.0/lib/python3.6/site-packages/matplotlib/mlab.py:282: RuntimeWarning: invalid value encountered in multiply
#   return windowValsRep * x, windowVals
# /Users/neko/.pyenv/versions/anaconda3-4.4.0/lib/python3.6/site-packages/matplotlib/mlab.py:730: RuntimeWarning: overflow encountered in multiply
#   result = np.conjugate(result) * result
# /Users/neko/.pyenv/versions/anaconda3-4.4.0/lib/python3.6/site-packages/matplotlib/mlab.py:730: RuntimeWarning: invalid value encountered in multiply
#   result = np.conjugate(result) * result
# /Users/neko/.pyenv/versions/anaconda3-4.4.0/lib/python3.6/site-packages/matplotlib/mlab.py:752: RuntimeWarning: overflow encountered in multiply
#   result[slc] *= scaling_factor
# /Users/neko/.pyenv/versions/anaconda3-4.4.0/lib/python3.6/site-packages/matplotlib/mlab.py:752: RuntimeWarning: invalid value encountered in multiply
#   result[slc] *= scaling_factor
# /Users/neko/.pyenv/versions/anaconda3-4.4.0/lib/python3.6/site-packages/matplotlib/mlab.py:758: RuntimeWarning: invalid value encountered in true_divide
#   result /= Fs
# /Users/neko/.pyenv/versions/anaconda3-4.4.0/lib/python3.6/site-packages/matplotlib/mlab.py:761: RuntimeWarning: invalid value encountered in true_divide
#   result /= (np.abs(windowVals)**2).sum()
