# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import pickle
import csv
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
#vine linux
#f = pd.read_csv('/home/hera/nodoka/home2/nodoka/spike-data/25kHz-data/B36 Rd.csv',header=None)
#f.to_pickle('/home/nodoka/spike-data/25kHz-data/B36 Rd.pickle')

#mac
f = pd.read_csv('/Volumes/NO NAME/25kHz-data/B36 Rd.csv',header=None)
f.to_pickle('/Volumes/NO NAME/25kHz-data/B36 Rd.pickle')

#ubuntu
#f = pd.read_csv('/home/hera/nodoka/home2/nodoka/spike-data/25kHz-data/B36 Rd.csv',header=None)
#f.to_pickle('/home/nodoka/spike-data/25kHz-data/B36 Rd.pickle')

# %%
import pickle
import numpy as np
import wave
from pylab import *
#with open('/home/hera/nodoka/home2/nodoka/spike-data/25kHz-data/B36 Rd.pickle', mode='rb') as fp:
#with open('/home/hera/nodoka/home2/nodoka/spike-data/25kHz-data/B36 Rd.pickle', mode='rb') as fp:
with open('/Volumes/NO NAME/25kHz-data/B36 Rd.pickle',mode='rb') as fp:
    df = pickle.load(fp)

start = 1000
end = 2000

plt.plot(df[start:end])

#data = df.dataframe([0], dtype='float')
#data = (pd.Series(df[start:end], dtype=np.float64))
data = df.as_matrix(0,)#[start:end]
specdata = data[start:end]
print(specdata)
length = end - start
print(length)
N = 512
hammingWindow = np.hamming(N)
samplingrate = 25000

# FFTで用いるハミング窓
hammingWindow = np.hamming(N)

# スペクトログラムを描画
pxx, freqs, bins, im = plt.specgram(data, NFFT=N, Fs=samplingrate, noverlap=0, window=hammingWindow)
axis([0, length, 0, samplingrate / 2])
xlabel("time [second]")
ylabel("frequency [Hz]")

show()
df.close()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-58-47d9f127b45b> in <module>()
#      15 #data = df.dataframe([0], dtype='float')
#      16 #data = (pd.Series(df[start:end], dtype=np.float64))
# ---> 17 data = df.as_matrix(0,)#[start:end]
#      18 specdata = data[start:end]
#      19 print(specdata)
#
# /Users/neko/.pyenv/versions/anaconda3-4.4.0/lib/python3.6/site-packages/pandas/core/generic.py in as_matrix(self, columns)
#    3140         self._consolidate_inplace()
#    3141         if self._AXIS_REVERSED:
# -> 3142             return self._data.as_matrix(columns).T
#    3143         return self._data.as_matrix(columns)
#    3144
#
# /Users/neko/.pyenv/versions/anaconda3-4.4.0/lib/python3.6/site-packages/pandas/core/internals.py in as_matrix(self, items)
#    3441
#    3442         if items is not None:
# -> 3443             mgr = self.reindex_axis(items, axis=0)
#    3444         else:
#    3445             mgr = self
#
# /Users/neko/.pyenv/versions/anaconda3-4.4.0/lib/python3.6/site-packages/pandas/core/internals.py in reindex_axis(self, new_index, axis, method, limit, fill_value, copy)
#    3851         Conform block manager to new index.
#    3852         """
# -> 3853         new_index = _ensure_index(new_index)
#    3854         new_index, indexer = self.axes[axis].reindex(new_index, method=method,
#    3855                                                      limit=limit)
#
# /Users/neko/.pyenv/versions/anaconda3-4.4.0/lib/python3.6/site-packages/pandas/core/indexes/base.py in _ensure_index(index_like, copy)
#    3976             index_like = copy(index_like)
#    3977
# -> 3978     return Index(index_like)
#    3979
#    3980
#
# /Users/neko/.pyenv/versions/anaconda3-4.4.0/lib/python3.6/site-packages/pandas/core/indexes/base.py in __new__(cls, data, dtype, copy, name, fastpath, tupleize_cols, **kwargs)
#     324                          **kwargs)
#     325         elif data is None or is_scalar(data):
# --> 326             cls._scalar_data_error(data)
#     327         else:
#     328             if (tupleize_cols and isinstance(data, list) and data and
#
# /Users/neko/.pyenv/versions/anaconda3-4.4.0/lib/python3.6/site-packages/pandas/core/indexes/base.py in _scalar_data_error(cls, data)
#     676         raise TypeError('{0}(...) must be called with a collection of some '
#     677                         'kind, {1} was passed'.format(cls.__name__,
# --> 678                                                       repr(data)))
#     679
#     680     @classmethod
#
# TypeError: Index(...) must be called with a collection of some kind, 0 was passed
