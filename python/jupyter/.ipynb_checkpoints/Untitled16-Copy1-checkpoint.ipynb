# %%
#エクセルファイルの変換を目指して
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
file_name = 'B39 restraint R2'
file = pd.ExcelFile(file_name+'.xls')
#all_df = pd.DataFrame()
time_file = open(file_name+'_time_data.csv', 'w')


sheet_df = file.parse(file.sheet_names, header=None)
all_df = pd.DataFrame()

sheet_names = file.sheet_names
for j, name in enumerate(sheet_names):
    sheet_df[j] = file.parse(name)
    
for i, name in enumerate(sheet_names):
    sheet_df[i] = file.parse(name)
    end_number = (np.where(sheet_df[i]['INFORMATION']=="CHANNEL")[0][1])
    sig1 = (sheet_df[i]['INFORMATION'][21:end_number-2])
    sig1 = sig1 - sig1.mean()

    for j in range(0, 30):
        end_number = (np.where(sheet_df[j]['INFORMATION']=="CHANNEL")[0][1])
        sig2 = (sheet_df[j]['INFORMATION'][21:end_number-2])
        sig2 = sig2 - sig2.mean()
        corr = np.correlate(sig1, sig2, "full")
        estimated_delay = corr.argmax() - (len(sig1) - 1)
        print("estimated delay is " + str(estimated_delay)+ "_" + str(i) +"_"+ str(j))

        plt.figure(figsize=(6, 4), dpi=30)
        plt.subplots_adjust(wspace=0.4, hspace=0.6)
        plt.subplot(4, 1, 1)
        plt.ylabel("sig"+str(i))
        plt.plot(sig1)
        
        plt.subplot(4, 1, 2)
        plt.ylabel("sig"+str(j))
        plt.plot(sig2, color="g")

        plt.subplot(4, 1, 3)
        plt.ylabel("fit")
        plt.plot(np.arange(len(sig1)), sig1)
        plt.plot(np.arange(len(sig2)) + estimated_delay, sig2 )
        plt.xlim([0, len(sig1)])

        plt.subplot(4, 1, 4)
        plt.ylabel("corr")
        plt.plot(np.arange(len(corr)) - len(sig2) + 1, corr, color="r")
        plt.xlim([0, len(sig1)])
        #plt.show()
        print(i,j)
        plt.plot()
        #plt.savefig("./image2/"+ str(i) +"_"+ str(j) +".png")
        

file.close()
time_file.close()
#print(all_df)

#import xlrd
#file = xlrd.open_workbook('B39 restraint R2.xls')
#print(file.nsheets)

#all_df.to_csv("otamesi.csv", header=False, index=False)
# Out:
# estimated delay is 0_0_0
# 0 0
# estimated delay is -118_0_1
# 0 1
# estimated delay is -99_0_2
# 0 2
# estimated delay is -538_0_3
# 0 3
# estimated delay is -502_0_4
# 0 4
# estimated delay is -608_0_5
# 0 5
# estimated delay is -13_0_6
# 0 6
# estimated delay is -14_0_7
# 0 7
# estimated delay is 355_0_8
# 0 8
# estimated delay is 481_0_9
# 0 9
# estimated delay is -455_0_10
# 0 10
# estimated delay is -306_0_11
# 0 11
# estimated delay is -23_0_12
# 0 12
# estimated delay is -43_0_13
# 0 13
# estimated delay is 194_0_14
# 0 14
# estimated delay is -460_0_15
# 0 15
# estimated delay is -52_0_16
# 0 16
# estimated delay is -96_0_17
# 0 17
# estimated delay is -226_0_18
# 0 18
# estimated delay is -609_0_19
# 0 19
# estimated delay is -60_0_20
# 0 20
# estimated delay is -174_0_21
# 0 21
# estimated delay is 593_0_22
# /home/hera/nodoka/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/matplotlib/pyplot.py:522: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# 0 22
# estimated delay is -105_0_23
# 0 23
# estimated delay is -350_0_24
# 0 24
# estimated delay is 569_0_25
# 0 25
# estimated delay is 875_0_26
# 0 26
# estimated delay is 1_0_27
# 0 27
# estimated delay is -55_0_28
# 0 28
# estimated delay is 272_0_29
# 0 29
# estimated delay is 118_1_0
# 1 0
# estimated delay is 0_1_1
# 1 1
# estimated delay is -61_1_2
# 1 2
# estimated delay is -100_1_3
# 1 3
# estimated delay is -381_1_4
# 1 4
# estimated delay is 243_1_5
# 1 5
# estimated delay is -442_1_6
# 1 6
# estimated delay is -121_1_7
# 1 7
# estimated delay is 363_1_8
# 1 8
# estimated delay is 143_1_9
# 1 9
# estimated delay is -206_1_10
# 1 10
# estimated delay is -181_1_11
# 1 11
# estimated delay is -145_1_12
# 1 12
# estimated delay is 1151_1_13
# 1 13
# estimated delay is -125_1_14
# 1 14
# estimated delay is -336_1_15
# 1 15
# estimated delay is 195_1_16
# 1 16
# estimated delay is -189_1_17
# 1 17
# estimated delay is 9_1_18
# 1 18
# estimated delay is -499_1_19
# 1 19
# estimated delay is -46_1_20
# 1 20
# estimated delay is -50_1_21
# 1 21
# estimated delay is 783_1_22
# 1 22
# estimated delay is 153_1_23
# 1 23
# estimated delay is -449_1_24
# 1 24
# estimated delay is 558_1_25
# 1 25
# estimated delay is 789_1_26
# 1 26
# estimated delay is 126_1_27
# 1 27
# estimated delay is 671_1_28
# 1 28
# estimated delay is 652_1_29
# 1 29
# estimated delay is 99_2_0
# 2 0
# estimated delay is 61_2_1
# 2 1
# estimated delay is 0_2_2
# 2 2
# estimated delay is -122_2_3
# 2 3
# estimated delay is -390_2_4
# 2 4
# estimated delay is -446_2_5
# 2 5
# estimated delay is -14_2_6
# 2 6
# estimated delay is -257_2_7
# 2 7
# estimated delay is 545_2_8
# 2 8
# estimated delay is -110_2_9
# 2 9
# estimated delay is -137_2_10
# 2 10
# estimated delay is -117_2_11
# 2 11
# estimated delay is -346_2_12
# 2 12
# estimated delay is 1214_2_13
# 2 13
# estimated delay is 289_2_14
# 2 14
# estimated delay is -172_2_15
# 2 15
# estimated delay is -665_2_16
# 2 16
# estimated delay is -322_2_17
# 2 17
# estimated delay is -119_2_18
# 2 18
# estimated delay is -519_2_19
# 2 19
# estimated delay is 124_2_20
# 2 20
# estimated delay is -168_2_21
# 2 21
# estimated delay is 768_2_22
# 2 22
# estimated delay is 421_2_23
# 2 23
# estimated delay is -380_2_24
# 2 24
# estimated delay is 555_2_25
# 2 25
# estimated delay is -3_2_26
# 2 26
# estimated delay is 327_2_27
# 2 27
# estimated delay is 488_2_28
# 2 28
# estimated delay is 456_2_29
# 2 29
# estimated delay is 538_3_0
# 3 0
# estimated delay is 100_3_1
# 3 1
# estimated delay is 122_3_2
# 3 2
# estimated delay is 0_3_3
# 3 3
# estimated delay is -39_3_4
# 3 4
# estimated delay is -81_3_5
# 3 5
# estimated delay is -259_3_6
# 3 6
# estimated delay is 58_3_7
# 3 7
# estimated delay is 1090_3_8
# 3 8
# estimated delay is 245_3_9
# 3 9
# estimated delay is -273_3_10
# 3 10
# estimated delay is 2_3_11
# 3 11
# estimated delay is 196_3_12
# 3 12
# estimated delay is 1083_3_13
# 3 13
# estimated delay is 127_3_14
# 3 14
# estimated delay is -405_3_15
# 3 15
# estimated delay is -128_3_16
# 3 16
# estimated delay is 132_3_17
# 3 17
# estimated delay is -3_3_18
# 3 18
# estimated delay is -71_3_19
# 3 19
# estimated delay is 253_3_20
# 3 20
# estimated delay is -121_3_21
# 3 21
# estimated delay is 369_3_22
# 3 22
# estimated delay is -21_3_23
# 3 23
# estimated delay is 242_3_24
# 3 24
# estimated delay is 495_3_25
# 3 25
# estimated delay is 1105_3_26
# 3 26
# estimated delay is 106_3_27
# 3 27
# estimated delay is 121_3_28
# 3 28
# estimated delay is 578_3_29
# 3 29
# estimated delay is 502_4_0
# 4 0
# estimated delay is 381_4_1
# 4 1
# estimated delay is 390_4_2
# 4 2
# estimated delay is 39_4_3
# 4 3
# estimated delay is 0_4_4
# 4 4
# estimated delay is 112_4_5
# 4 5
# estimated delay is -602_4_6
# 4 6
# estimated delay is 326_4_7
# 4 7
# estimated delay is 747_4_8
# 4 8
# estimated delay is 794_4_9
# 4 9
# estimated delay is -79_4_10
# 4 10
# estimated delay is 190_4_11
# 4 11
# estimated delay is 1135_4_12
# 4 12
# estimated delay is 172_4_13
# 4 13
# estimated delay is 318_4_14
# 4 14
# estimated delay is 405_4_15
# 4 15
# estimated delay is -88_4_16
# 4 16
# estimated delay is 262_4_17
# 4 17
# estimated delay is -263_4_18
# 4 18
# estimated delay is -119_4_19
# 4 19
# estimated delay is 517_4_20
# 4 20
# estimated delay is 325_4_21
# 4 21
# estimated delay is 1092_4_22
# 4 22
# estimated delay is 738_4_23
# 4 23
# estimated delay is 286_4_24
# 4 24
# estimated delay is 836_4_25
# 4 25
# estimated delay is 1142_4_26
# 4 26
# estimated delay is 300_4_27
# 4 27
# estimated delay is 387_4_28
# 4 28
# estimated delay is 771_4_29
# 4 29
# estimated delay is 608_5_0
# 5 0
# estimated delay is -243_5_1
# 5 1
# estimated delay is 446_5_2
# 5 2
# estimated delay is 81_5_3
# 5 3
# estimated delay is -112_5_4
# 5 4
# estimated delay is 0_5_5
# 5 5
# estimated delay is 33_5_6
# 5 6
# estimated delay is 289_5_7
# 5 7
# estimated delay is 574_5_8
# 5 8
# estimated delay is 15_5_9
# 5 9
# estimated delay is -443_5_10
# 5 10
# estimated delay is 169_5_11
# 5 11
# estimated delay is 501_5_12
# 5 12
# estimated delay is 210_5_13
# 5 13
# estimated delay is 70_5_14
# 5 14
# estimated delay is -483_5_15
# 5 15
# estimated delay is 192_5_16
# 5 16
# estimated delay is 18_5_17
# 5 17
# estimated delay is -181_5_18
# 5 18
# estimated delay is -153_5_19
# 5 19
# estimated delay is 274_5_20
# 5 20
# estimated delay is -301_5_21
# 5 21
# estimated delay is 294_5_22
# 5 22
# estimated delay is 212_5_23
# 5 23
# estimated delay is 254_5_24
# 5 24
# estimated delay is 1100_5_25
# 5 25
# estimated delay is 1180_5_26
# 5 26
# estimated delay is 118_5_27
# 5 27
# estimated delay is 118_5_28
# 5 28
# estimated delay is 399_5_29
# 5 29
# estimated delay is 13_6_0
# 6 0
# estimated delay is 442_6_1
# 6 1
# estimated delay is 14_6_2
# 6 2
# estimated delay is 259_6_3
# 6 3
# estimated delay is 602_6_4
# 6 4
# estimated delay is -33_6_5
# 6 5
# estimated delay is 0_6_6
# 6 6
# estimated delay is -233_6_7
# 6 7
# estimated delay is 1152_6_8
# 6 8
# estimated delay is 504_6_9
# 6 9
# estimated delay is 163_6_10
# 6 10
# estimated delay is -177_6_11
# 6 11
# estimated delay is 457_6_12
# 6 12
# estimated delay is 153_6_13
# 6 13
# estimated delay is 328_6_14
# 6 14
# estimated delay is -144_6_15
# 6 15
# estimated delay is 218_6_16
# 6 16
# estimated delay is 810_6_17
# 6 17
# estimated delay is 339_6_18
# 6 18
# estimated delay is 94_6_19
# 6 19
# estimated delay is 51_6_20
# 6 20
# estimated delay is -156_6_21
# 6 21
# estimated delay is 880_6_22
# 6 22
# estimated delay is 264_6_23
# 6 23
# estimated delay is -194_6_24
# 6 24
# estimated delay is 760_6_25
# 6 25
# estimated delay is 1441_6_26
# 6 26
# estimated delay is 365_6_27
# 6 27
# estimated delay is 323_6_28
# 6 28
# estimated delay is 864_6_29
# 6 29
# estimated delay is 14_7_0
# 7 0
# estimated delay is 121_7_1
# 7 1
# estimated delay is 257_7_2
# 7 2
# estimated delay is -58_7_3
# 7 3
# estimated delay is -326_7_4
# 7 4
# estimated delay is -289_7_5
# 7 5
# estimated delay is 233_7_6
# 7 6
# estimated delay is 0_7_7
# 7 7
# estimated delay is 926_7_8
# 7 8
# estimated delay is 359_7_9
# 7 9
# estimated delay is -331_7_10
# 7 10
# estimated delay is -61_7_11
# 7 11
# estimated delay is 699_7_12
# 7 12
# estimated delay is -179_7_13
# 7 13
# estimated delay is -21_7_14
# 7 14
# estimated delay is -212_7_15
# 7 15
# estimated delay is -405_7_16
# 7 16
# estimated delay is -283_7_17
# 7 17
# estimated delay is -221_7_18
# 7 18
# estimated delay is -45_7_19
# 7 19
# estimated delay is 181_7_20
# 7 20
# estimated delay is 75_7_21
# 7 21
# estimated delay is 739_7_22
# 7 22
# estimated delay is 486_7_23
# 7 23
# estimated delay is -337_7_24
# 7 24
# estimated delay is 1120_7_25
# 7 25
# estimated delay is 824_7_26
# 7 26
# estimated delay is 25_7_27
# 7 27
# estimated delay is 193_7_28
# 7 28
# estimated delay is 418_7_29
# 7 29
# estimated delay is -355_8_0
# 8 0
# estimated delay is -363_8_1
# 8 1
# estimated delay is -545_8_2
# 8 2
# estimated delay is -1090_8_3
# 8 3
# estimated delay is -747_8_4
# 8 4
# estimated delay is -574_8_5
# 8 5
# estimated delay is -1152_8_6
# 8 6
# estimated delay is -926_8_7
# 8 7
# estimated delay is 0_8_8
# 8 8
# estimated delay is -558_8_9
# 8 9
# estimated delay is -911_8_10
# 8 10
# estimated delay is -662_8_11
# 8 11
# estimated delay is -385_8_12
# 8 12
# estimated delay is 672_8_13
# 8 13
# estimated delay is -609_8_14
# 8 14
# estimated delay is -817_8_15
# 8 15
# estimated delay is -768_8_16
# 8 16
# estimated delay is -342_8_17
# 8 17
# estimated delay is -465_8_18
# 8 18
# estimated delay is -1061_8_19
# 8 19
# estimated delay is -747_8_20
# 8 20
# estimated delay is -220_8_21
# 8 21
# estimated delay is 5_8_22
# 8 22
# estimated delay is -539_8_23
# 8 23
# estimated delay is -704_8_24
# 8 24
# estimated delay is 88_8_25
# 8 25
# estimated delay is -130_8_26
# 8 26
# estimated delay is -449_8_27
# 8 27
# estimated delay is -159_8_28
# 8 28
# estimated delay is -179_8_29
# 8 29
# estimated delay is -481_9_0
# 9 0
# estimated delay is -143_9_1
# 9 1
# estimated delay is 110_9_2
# 9 2
# estimated delay is -245_9_3
# 9 3
# estimated delay is -794_9_4
# 9 4
# estimated delay is -15_9_5
# 9 5
# estimated delay is -504_9_6
# 9 6
# estimated delay is -359_9_7
# 9 7
# estimated delay is 558_9_8
# 9 8
# estimated delay is 0_9_9
# 9 9
# estimated delay is -784_9_10
# 9 10
# estimated delay is -785_9_11
# 9 11
# estimated delay is 175_9_12
# 9 12
# estimated delay is -609_9_13
# 9 13
# estimated delay is -383_9_14
# 9 14
# estimated delay is -650_9_15
# 9 15
# estimated delay is -756_9_16
# 9 16
# estimated delay is 12_9_17
# 9 17
# estimated delay is -454_9_18
# 9 18
# estimated delay is -411_9_19
# 9 19
# estimated delay is -735_9_20
# 9 20
# estimated delay is -465_9_21
# 9 21
# estimated delay is 21_9_22
# 9 22
# estimated delay is -523_9_23
# 9 23
# estimated delay is -776_9_24
# 9 24
# estimated delay is -101_9_25
# 9 25
# estimated delay is 395_9_26
# 9 26
# estimated delay is -681_9_27
# 9 27
# estimated delay is 360_9_28
# 9 28
# estimated delay is 124_9_29
# 9 29
# estimated delay is 455_10_0
# 10 0
# estimated delay is 206_10_1
# 10 1
# estimated delay is 137_10_2
# 10 2
# estimated delay is 273_10_3
# 10 3
# estimated delay is 79_10_4
# 10 4
# estimated delay is 443_10_5
# 10 5
# estimated delay is -163_10_6
# 10 6
# estimated delay is 331_10_7
# 10 7
# estimated delay is 911_10_8
# 10 8
# estimated delay is 784_10_9
# 10 9
# estimated delay is 0_10_10
# 10 10
# estimated delay is 365_10_11
# 10 11
# estimated delay is 1216_10_12
# 10 12
# estimated delay is 252_10_13
# 10 13
# estimated delay is 870_10_14
# 10 14
# estimated delay is -131_10_15
# 10 15
# estimated delay is 397_10_16
# 10 16
# estimated delay is 350_10_17
# 10 17
# estimated delay is 461_10_18
# 10 18
# estimated delay is -272_10_19
# 10 19
# estimated delay is 63_10_20
# 10 20
# estimated delay is 404_10_21
# 10 21
# estimated delay is 894_10_22
# 10 22
# estimated delay is 254_10_23
# 10 23
# estimated delay is 296_10_24
# 10 24
# estimated delay is 772_10_25
# 10 25
# estimated delay is 1455_10_26
# 10 26
# estimated delay is 473_10_27
# 10 27
# estimated delay is 873_10_28
# 10 28
# estimated delay is 851_10_29
# 10 29
# estimated delay is 306_11_0
# 11 0
# estimated delay is 181_11_1
# 11 1
# estimated delay is 117_11_2
# 11 2
# estimated delay is -2_11_3
# 11 3
# estimated delay is -190_11_4
# 11 4
# estimated delay is -169_11_5
# 11 5
# estimated delay is 177_11_6
# 11 6
# estimated delay is 61_11_7
# 11 7
# estimated delay is 662_11_8
# 11 8
# estimated delay is 785_11_9
# 11 9
# estimated delay is -365_11_10
# 11 10
# estimated delay is 0_11_11
# 11 11
# estimated delay is 186_11_12
# 11 12
# estimated delay is -118_11_13
# 11 13
# estimated delay is 498_11_14
# 11 14
# estimated delay is -152_11_15
# 11 15
# estimated delay is 24_11_16
# 11 16
# estimated delay is -13_11_17
# 11 17
# estimated delay is 194_11_18
# 11 18
# estimated delay is -400_11_19
# 11 19
# estimated delay is 247_11_20
# 11 20
# estimated delay is 26_11_21
# 11 21
# estimated delay is 364_11_22
# 11 22
# estimated delay is -118_11_23
# 11 23
# estimated delay is 86_11_24
# 11 24
# estimated delay is 639_11_25
# 11 25
# estimated delay is 953_11_26
# 11 26
# estimated delay is 442_11_27
# 11 27
# estimated delay is 507_11_28
# 11 28
# estimated delay is 478_11_29
# 11 29
# estimated delay is 23_12_0
# 12 0
# estimated delay is 145_12_1
# 12 1
# estimated delay is 346_12_2
# 12 2
# estimated delay is -196_12_3
# 12 3
# estimated delay is -1135_12_4
# 12 4
# estimated delay is -501_12_5
# 12 5
# estimated delay is -457_12_6
# 12 6
# estimated delay is -699_12_7
# 12 7
# estimated delay is 385_12_8
# 12 8
# estimated delay is -175_12_9
# 12 9
# estimated delay is -1216_12_10
# 12 10
# estimated delay is -186_12_11
# 12 11
# estimated delay is 0_12_12
# 12 12
# estimated delay is 128_12_13
# 12 13
# estimated delay is -442_12_14
# 12 14
# estimated delay is -424_12_15
# 12 15
# estimated delay is -453_12_16
# 12 16
# estimated delay is 35_12_17
# 12 17
# estimated delay is -683_12_18
# 12 18
# estimated delay is -262_12_19
# 12 19
# estimated delay is 55_12_20
# 12 20
# estimated delay is 283_12_21
# 12 21
# estimated delay is 328_12_22
# 12 22
# estimated delay is -217_12_23
# 12 23
# estimated delay is -546_12_24
# 12 24
# estimated delay is 306_12_25
# 12 25
# estimated delay is 1089_12_26
# 12 26
# estimated delay is -189_12_27
# 12 27
# estimated delay is -163_12_28
# 12 28
# estimated delay is 295_12_29
# 12 29
# estimated delay is 43_13_0
# 13 0
# estimated delay is -1151_13_1
# 13 1
# estimated delay is -1214_13_2
# 13 2
# estimated delay is -1083_13_3
# 13 3
# estimated delay is -172_13_4
# 13 4
# estimated delay is -210_13_5
# 13 5
# estimated delay is -153_13_6
# 13 6
# estimated delay is 179_13_7
# 13 7
# estimated delay is -672_13_8
# 13 8
# estimated delay is 609_13_9
# 13 9
# estimated delay is -252_13_10
# 13 10
# estimated delay is 118_13_11
# 13 11
# estimated delay is -128_13_12
# 13 12
# estimated delay is 0_13_13
# 13 13
# estimated delay is -194_13_14
# 13 14
# estimated delay is -1487_13_15
# 13 15
# estimated delay is -19_13_16
# 13 16
# estimated delay is -105_13_17
# 13 17
# estimated delay is -185_13_18
# 13 18
# estimated delay is -50_13_19
# 13 19
# estimated delay is -1281_13_20
# 13 20
# estimated delay is 154_13_21
# 13 21
# estimated delay is -714_13_22
# 13 22
# estimated delay is 1_13_23
# 13 23
# estimated delay is -243_13_24
# 13 24
# estimated delay is -160_13_25
# 13 25
# estimated delay is 917_13_26
# 13 26
# estimated delay is -882_13_27
# 13 27
# estimated delay is 625_13_28
# 13 28
# estimated delay is 599_13_29
# 13 29
# estimated delay is -194_14_0
# 14 0
# estimated delay is 125_14_1
# 14 1
# estimated delay is -289_14_2
# 14 2
# estimated delay is -127_14_3
# 14 3
# estimated delay is -318_14_4
# 14 4
# estimated delay is -70_14_5
# 14 5
# estimated delay is -328_14_6
# 14 6
# estimated delay is 21_14_7
# 14 7
# estimated delay is 609_14_8
# 14 8
# estimated delay is 383_14_9
# 14 9
# estimated delay is -870_14_10
# 14 10
# estimated delay is -498_14_11
# 14 11
# estimated delay is 442_14_12
# 14 12
# estimated delay is 194_14_13
# 14 13
# estimated delay is 0_14_14
# 14 14
# estimated delay is 8_14_15
# 14 15
# estimated delay is -378_14_16
# 14 16
# estimated delay is -271_14_17
# 14 17
# estimated delay is -61_14_18
# 14 18
# estimated delay is -443_14_19
# 14 19
# estimated delay is -355_14_20
# 14 20
# estimated delay is -467_14_21
# 14 21
# estimated delay is 830_14_22
# 14 22
# estimated delay is -164_14_23
# 14 23
# estimated delay is -575_14_24
# 14 24
# estimated delay is 368_14_25
# 14 25
# estimated delay is 843_14_26
# 14 26
# estimated delay is 38_14_27
# 14 27
# estimated delay is 2_14_28
# 14 28
# estimated delay is 95_14_29
# 14 29
# estimated delay is 460_15_0
# 15 0
# estimated delay is 336_15_1
# 15 1
# estimated delay is 172_15_2
# 15 2
# estimated delay is 405_15_3
# 15 3
# estimated delay is -405_15_4
# 15 4
# estimated delay is 483_15_5
# 15 5
# estimated delay is 144_15_6
# 15 6
# estimated delay is 212_15_7
# 15 7
# estimated delay is 817_15_8
# 15 8
# estimated delay is 650_15_9
# 15 9
# estimated delay is 131_15_10
# 15 10
# estimated delay is 152_15_11
# 15 11
# estimated delay is 424_15_12
# 15 12
# estimated delay is 1487_15_13
# 15 13
# estimated delay is -8_15_14
# 15 14
# estimated delay is 0_15_15
# 15 15
# estimated delay is 279_15_16
# 15 16
# estimated delay is 852_15_17
# 15 17
# estimated delay is 236_15_18
# 15 18
# estimated delay is 84_15_19
# 15 19
# estimated delay is 297_15_20
# 15 20
# estimated delay is 286_15_21
# 15 21
# estimated delay is 391_15_22
# 15 22
# estimated delay is 34_15_23
# 15 23
# estimated delay is -27_15_24
# 15 24
# estimated delay is 898_15_25
# 15 25
# estimated delay is 1519_15_26
# 15 26
# estimated delay is 508_15_27
# 15 27
# estimated delay is 270_15_28
# 15 28
# estimated delay is 631_15_29
# 15 29
# estimated delay is 52_16_0
# 16 0
# estimated delay is -195_16_1
# 16 1
# estimated delay is 665_16_2
# 16 2
# estimated delay is 128_16_3
# 16 3
# estimated delay is 88_16_4
# 16 4
# estimated delay is -192_16_5
# 16 5
# estimated delay is -218_16_6
# 16 6
# estimated delay is 405_16_7
# 16 7
# estimated delay is 768_16_8
# 16 8
# estimated delay is 756_16_9
# 16 9
# estimated delay is -397_16_10
# 16 10
# estimated delay is -24_16_11
# 16 11
# estimated delay is 453_16_12
# 16 12
# estimated delay is 19_16_13
# 16 13
# estimated delay is 378_16_14
# 16 14
# estimated delay is -279_16_15
# 16 15
# estimated delay is 0_16_16
# 16 16
# estimated delay is 121_16_17
# 16 17
# estimated delay is -173_16_18
# 16 18
# estimated delay is -425_16_19
# 16 19
# estimated delay is -63_16_20
# 16 20
# estimated delay is 6_16_21
# 16 21
# estimated delay is 498_16_22
# 16 22
# estimated delay is -144_16_23
# 16 23
# estimated delay is 65_16_24
# 16 24
# estimated delay is 374_16_25
# 16 25
# estimated delay is 1226_16_26
# 16 26
# estimated delay is -18_16_27
# 16 27
# estimated delay is 482_16_28
# 16 28
# estimated delay is 453_16_29
# 16 29
# estimated delay is 96_17_0
# 17 0
# estimated delay is 189_17_1
# 17 1
# estimated delay is 322_17_2
# 17 2
# estimated delay is -132_17_3
# 17 3
# estimated delay is -262_17_4
# 17 4
# estimated delay is -18_17_5
# 17 5
# estimated delay is -810_17_6
# 17 6
# estimated delay is 283_17_7
# 17 7
# estimated delay is 342_17_8
# 17 8
# estimated delay is -12_17_9
# 17 9
# estimated delay is -350_17_10
# 17 10
# estimated delay is 13_17_11
# 17 11
# estimated delay is -35_17_12
# 17 12
# estimated delay is 105_17_13
# 17 13
# estimated delay is 271_17_14
# 17 14
# estimated delay is -852_17_15
# 17 15
# estimated delay is -121_17_16
# 17 16
# estimated delay is 0_17_17
# 17 17
# estimated delay is -130_17_18
# 17 18
# estimated delay is -384_17_19
# 17 19
# estimated delay is 256_17_20
# 17 20
# estimated delay is -666_17_21
# 17 21
# estimated delay is 456_17_22
# 17 22
# estimated delay is -255_17_23
# 17 23
# estimated delay is -56_17_24
# 17 24
# estimated delay is 627_17_25
# 17 25
# estimated delay is 148_17_26
# 17 26
# estimated delay is 310_17_27
# 17 27
# estimated delay is 523_17_28
# 17 28
# estimated delay is -221_17_29
# 17 29
# estimated delay is 226_18_0
# 18 0
# estimated delay is -9_18_1
# 18 1
# estimated delay is 119_18_2
# 18 2
# estimated delay is 3_18_3
# 18 3
# estimated delay is 263_18_4
# 18 4
# estimated delay is 181_18_5
# 18 5
# estimated delay is -339_18_6
# 18 6
# estimated delay is 221_18_7
# 18 7
# estimated delay is 465_18_8
# 18 8
# estimated delay is 454_18_9
# 18 9
# estimated delay is -461_18_10
# 18 10
# estimated delay is -194_18_11
# 18 11
# estimated delay is 683_18_12
# 18 12
# estimated delay is 185_18_13
# 18 13
# estimated delay is 61_18_14
# 18 14
# estimated delay is -236_18_15
# 18 15
# estimated delay is 173_18_16
# 18 16
# estimated delay is 130_18_17
# 18 17
# estimated delay is 0_18_18
# 18 18
# estimated delay is -310_18_19
# 18 19
# estimated delay is -284_18_20
# 18 20
# estimated delay is -122_18_21
# 18 21
# estimated delay is -291_18_22
# 18 22
# estimated delay is 422_18_23
# 18 23
# estimated delay is 380_18_24
# 18 24
# estimated delay is 490_18_25
# 18 25
# estimated delay is 1230_18_26
# 18 26
# estimated delay is 119_18_27
# 18 27
# estimated delay is 476_18_28
# 18 28
# estimated delay is 628_18_29
# 18 29
# estimated delay is 609_19_0
# 19 0
# estimated delay is 499_19_1
# 19 1
# estimated delay is 519_19_2
# 19 2
# estimated delay is 71_19_3
# 19 3
# estimated delay is 119_19_4
# 19 4
# estimated delay is 153_19_5
# 19 5
# estimated delay is -94_19_6
# 19 6
# estimated delay is 45_19_7
# 19 7
# estimated delay is 1061_19_8
# 19 8
# estimated delay is 411_19_9
# 19 9
# estimated delay is 272_19_10
# 19 10
# estimated delay is 400_19_11
# 19 11
# estimated delay is 262_19_12
# 19 12
# estimated delay is 50_19_13
# 19 13
# estimated delay is 443_19_14
# 19 14
# estimated delay is -84_19_15
# 19 15
# estimated delay is 425_19_16
# 19 16
# estimated delay is 384_19_17
# 19 17
# estimated delay is 310_19_18
# 19 18
# estimated delay is 0_19_19
# 19 19
# estimated delay is 427_19_20
# 19 20
# estimated delay is -178_19_21
# 19 21
# estimated delay is 692_19_22
# 19 22
# estimated delay is 51_19_23
# 19 23
# estimated delay is 129_19_24
# 19 24
# estimated delay is 1044_19_25
# 19 25
# estimated delay is 1349_19_26
# 19 26
# estimated delay is 622_19_27
# 19 27
# estimated delay is 787_19_28
# 19 28
# estimated delay is 886_19_29
# 19 29
# estimated delay is 60_20_0
# 20 0
# estimated delay is 46_20_1
# 20 1
# estimated delay is -124_20_2
# 20 2
# estimated delay is -253_20_3
# 20 3
# estimated delay is -517_20_4
# 20 4
# estimated delay is -274_20_5
# 20 5
# estimated delay is -51_20_6
# 20 6
# estimated delay is -181_20_7
# 20 7
# estimated delay is 747_20_8
# 20 8
# estimated delay is 735_20_9
# 20 9
# estimated delay is -63_20_10
# 20 10
# estimated delay is -247_20_11
# 20 11
# estimated delay is -55_20_12
# 20 12
# estimated delay is 1281_20_13
# 20 13
# estimated delay is 355_20_14
# 20 14
# estimated delay is -297_20_15
# 20 15
# estimated delay is 63_20_16
# 20 16
# estimated delay is -256_20_17
# 20 17
# estimated delay is 284_20_18
# 20 18
# estimated delay is -427_20_19
# 20 19
# estimated delay is 0_20_20
# 20 20
# estimated delay is -190_20_21
# 20 21
# estimated delay is 562_20_22
# 20 22
# estimated delay is 297_20_23
# 20 23
# estimated delay is -308_20_24
# 20 24
# estimated delay is 162_20_25
# 20 25
# estimated delay is 755_20_26
# 20 26
# estimated delay is 62_20_27
# 20 27
# estimated delay is 357_20_28
# 20 28
# estimated delay is 329_20_29
# 20 29
# estimated delay is 174_21_0
# 21 0
# estimated delay is 50_21_1
# 21 1
# estimated delay is 168_21_2
# 21 2
# estimated delay is 121_21_3
# 21 3
# estimated delay is -325_21_4
# 21 4
# estimated delay is 301_21_5
# 21 5
# estimated delay is 156_21_6
# 21 6
# estimated delay is -75_21_7
# 21 7
# estimated delay is 220_21_8
# 21 8
# estimated delay is 465_21_9
# 21 9
# estimated delay is -404_21_10
# 21 10
# estimated delay is -26_21_11
# 21 11
# estimated delay is -283_21_12
# 21 12
# estimated delay is -154_21_13
# 21 13
# estimated delay is 467_21_14
# 21 14
# estimated delay is -286_21_15
# 21 15
# estimated delay is -6_21_16
# 21 16
# estimated delay is 666_21_17
# 21 17
# estimated delay is 122_21_18
# 21 18
# estimated delay is 178_21_19
# 21 19
# estimated delay is 190_21_20
# 21 20
# estimated delay is 0_21_21
# 21 21
# estimated delay is 1121_21_22
# 21 22
# estimated delay is 413_21_23
# 21 23
# estimated delay is -110_21_24
# 21 24
# estimated delay is 1222_21_25
# 21 25
# estimated delay is 1224_21_26
# 21 26
# estimated delay is 806_21_27
# 21 27
# estimated delay is 476_21_28
# 21 28
# estimated delay is 446_21_29
# 21 29
# estimated delay is -593_22_0
# 22 0
# estimated delay is -783_22_1
# 22 1
# estimated delay is -768_22_2
# 22 2
# estimated delay is -369_22_3
# 22 3
# estimated delay is -1092_22_4
# 22 4
# estimated delay is -294_22_5
# 22 5
# estimated delay is -880_22_6
# 22 6
# estimated delay is -739_22_7
# 22 7
# estimated delay is -5_22_8
# 22 8
# estimated delay is -21_22_9
# 22 9
# estimated delay is -894_22_10
# 22 10
# estimated delay is -364_22_11
# 22 11
# estimated delay is -328_22_12
# 22 12
# estimated delay is 714_22_13
# 22 13
# estimated delay is -830_22_14
# 22 14
# estimated delay is -391_22_15
# 22 15
# estimated delay is -498_22_16
# 22 16
# estimated delay is -456_22_17
# 22 17
# estimated delay is 291_22_18
# 22 18
# estimated delay is -692_22_19
# 22 19
# estimated delay is -562_22_20
# 22 20
# estimated delay is -1121_22_21
# 22 21
# estimated delay is 0_22_22
# 22 22
# estimated delay is -354_22_23
# 22 23
# estimated delay is -514_22_24
# 22 24
# estimated delay is 278_22_25
# 22 25
# estimated delay is 887_22_26
# 22 26
# estimated delay is -793_22_27
# 22 27
# estimated delay is -344_22_28
# 22 28
# estimated delay is -43_22_29
# 22 29
# estimated delay is 105_23_0
# 23 0
# estimated delay is -153_23_1
# 23 1
# estimated delay is -421_23_2
# 23 2
# estimated delay is 21_23_3
# 23 3
# estimated delay is -738_23_4
# 23 4
# estimated delay is -212_23_5
# 23 5
# estimated delay is -264_23_6
# 23 6
# estimated delay is -486_23_7
# 23 7
# estimated delay is 539_23_8
# 23 8
# estimated delay is 523_23_9
# 23 9
# estimated delay is -254_23_10
# 23 10
# estimated delay is 118_23_11
# 23 11
# estimated delay is 217_23_12
# 23 12
# estimated delay is -1_23_13
# 23 13
# estimated delay is 164_23_14
# 23 14
# estimated delay is -34_23_15
# 23 15
# estimated delay is 144_23_16
# 23 16
# estimated delay is 255_23_17
# 23 17
# estimated delay is -422_23_18
# 23 18
# estimated delay is -51_23_19
# 23 19
# estimated delay is -297_23_20
# 23 20
# estimated delay is -413_23_21
# 23 21
# estimated delay is 354_23_22
# 23 22
# estimated delay is 0_23_23
# 23 23
# estimated delay is -161_23_24
# 23 24
# estimated delay is 1095_23_25
# 23 25
# estimated delay is 1073_23_26
# 23 26
# estimated delay is -370_23_27
# 23 27
# estimated delay is 55_23_28
# 23 28
# estimated delay is 599_23_29
# 23 29
# estimated delay is 350_24_0
# 24 0
# estimated delay is 449_24_1
# 24 1
# estimated delay is 380_24_2
# 24 2
# estimated delay is -242_24_3
# 24 3
# estimated delay is -286_24_4
# 24 4
# estimated delay is -254_24_5
# 24 5
# estimated delay is 194_24_6
# 24 6
# estimated delay is 337_24_7
# 24 7
# estimated delay is 704_24_8
# 24 8
# estimated delay is 776_24_9
# 24 9
# estimated delay is -296_24_10
# 24 10
# estimated delay is -86_24_11
# 24 11
# estimated delay is 546_24_12
# 24 12
# estimated delay is 243_24_13
# 24 13
# estimated delay is 575_24_14
# 24 14
# estimated delay is 27_24_15
# 24 15
# estimated delay is -65_24_16
# 24 16
# estimated delay is 56_24_17
# 24 17
# estimated delay is -380_24_18
# 24 18
# estimated delay is -129_24_19
# 24 19
# estimated delay is 308_24_20
# 24 20
# estimated delay is 110_24_21
# 24 21
# estimated delay is 514_24_22
# 24 22
# estimated delay is 161_24_23
# 24 23
# estimated delay is 0_24_24
# 24 24
# estimated delay is 851_24_25
# 24 25
# estimated delay is 1161_24_26
# 24 26
# estimated delay is -134_24_27
# 24 27
# estimated delay is 286_24_28
# 24 28
# estimated delay is 259_24_29
# 24 29
# estimated delay is -569_25_0
# 25 0
# estimated delay is -558_25_1
# 25 1
# estimated delay is -555_25_2
# 25 2
# estimated delay is -495_25_3
# 25 3
# estimated delay is -836_25_4
# 25 4
# estimated delay is -1100_25_5
# 25 5
# estimated delay is -760_25_6
# 25 6
# estimated delay is -1120_25_7
# 25 7
# estimated delay is -88_25_8
# 25 8
# estimated delay is 101_25_9
# 25 9
# estimated delay is -772_25_10
# 25 10
# estimated delay is -639_25_11
# 25 11
# estimated delay is -306_25_12
# 25 12
# estimated delay is 160_25_13
# 25 13
# estimated delay is -368_25_14
# 25 14
# estimated delay is -898_25_15
# 25 15
# estimated delay is -374_25_16
# 25 16
# estimated delay is -627_25_17
# 25 17
# estimated delay is -490_25_18
# 25 18
# estimated delay is -1044_25_19
# 25 19
# estimated delay is -162_25_20
# 25 20
# estimated delay is -1222_25_21
# 25 21
# estimated delay is -278_25_22
# 25 22
# estimated delay is -1095_25_23
# 25 23
# estimated delay is -851_25_24
# 25 24
# estimated delay is 0_25_25
# 25 25
# estimated delay is -286_25_26
# 25 26
# estimated delay is -326_25_27
# 25 27
# estimated delay is -756_25_28
# 25 28
# estimated delay is -781_25_29
# 25 29
# estimated delay is -875_26_0
# 26 0
# estimated delay is -789_26_1
# 26 1
# estimated delay is 3_26_2
# 26 2
# estimated delay is -1105_26_3
# 26 3
# estimated delay is -1142_26_4
# 26 4
# estimated delay is -1180_26_5
# 26 5
# estimated delay is -1441_26_6
# 26 6
# estimated delay is -824_26_7
# 26 7
# estimated delay is 130_26_8
# 26 8
# estimated delay is -395_26_9
# 26 9
# estimated delay is -1455_26_10
# 26 10
# estimated delay is -953_26_11
# 26 11
# estimated delay is -1089_26_12
# 26 12
# estimated delay is -917_26_13
# 26 13
# estimated delay is -843_26_14
# 26 14
# estimated delay is -1519_26_15
# 26 15
# estimated delay is -1226_26_16
# 26 16
# estimated delay is -148_26_17
# 26 17
# estimated delay is -1230_26_18
# 26 18
# estimated delay is -1349_26_19
# 26 19
# estimated delay is -755_26_20
# 26 20
# estimated delay is -1224_26_21
# 26 21
# estimated delay is -887_26_22
# 26 22
# estimated delay is -1073_26_23
# 26 23
# estimated delay is -1161_26_24
# 26 24
# estimated delay is 286_26_25
# 26 25
# estimated delay is 0_26_26
# 26 26
# estimated delay is -1400_26_27
# 26 27
# estimated delay is -627_26_28
# 26 28
# estimated delay is -370_26_29
# 26 29
# estimated delay is -1_27_0
# 27 0
# estimated delay is -126_27_1
# 27 1
# estimated delay is -327_27_2
# 27 2
# estimated delay is -106_27_3
# 27 3
# estimated delay is -300_27_4
# 27 4
# estimated delay is -118_27_5
# 27 5
# estimated delay is -365_27_6
# 27 6
# estimated delay is -25_27_7
# 27 7
# estimated delay is 449_27_8
# 27 8
# estimated delay is 681_27_9
# 27 9
# estimated delay is -473_27_10
# 27 10
# estimated delay is -442_27_11
# 27 11
# estimated delay is 189_27_12
# 27 12
# estimated delay is 882_27_13
# 27 13
# estimated delay is -38_27_14
# 27 14
# estimated delay is -508_27_15
# 27 15
# estimated delay is 18_27_16
# 27 16
# estimated delay is -310_27_17
# 27 17
# estimated delay is -119_27_18
# 27 18
# estimated delay is -622_27_19
# 27 19
# estimated delay is -62_27_20
# 27 20
# estimated delay is -806_27_21
# 27 21
# estimated delay is 793_27_22
# 27 22
# estimated delay is 370_27_23
# 27 23
# estimated delay is 134_27_24
# 27 24
# estimated delay is 326_27_25
# 27 25
# estimated delay is 1400_27_26
# 27 26
# estimated delay is 0_27_27
# 27 27
# estimated delay is 771_27_28
# 27 28
# estimated delay is 128_27_29
# 27 29
# estimated delay is 55_28_0
# 28 0
# estimated delay is -671_28_1
# 28 1
# estimated delay is -488_28_2
# 28 2
# estimated delay is -121_28_3
# 28 3
# estimated delay is -387_28_4
# 28 4
# estimated delay is -118_28_5
# 28 5
# estimated delay is -323_28_6
# 28 6
# estimated delay is -193_28_7
# 28 7
# estimated delay is 159_28_8
# 28 8
# estimated delay is -360_28_9
# 28 9
# estimated delay is -873_28_10
# 28 10
# estimated delay is -507_28_11
# 28 11
# estimated delay is 163_28_12
# 28 12
# estimated delay is -625_28_13
# 28 13
# estimated delay is -2_28_14
# 28 14
# estimated delay is -270_28_15
# 28 15
# estimated delay is -482_28_16
# 28 16
# estimated delay is -523_28_17
# 28 17
# estimated delay is -476_28_18
# 28 18
# estimated delay is -787_28_19
# 28 19
# estimated delay is -357_28_20
# 28 20
# estimated delay is -476_28_21
# 28 21
# estimated delay is 344_28_22
# 28 22
# estimated delay is -55_28_23
# 28 23
# estimated delay is -286_28_24
# 28 24
# estimated delay is 756_28_25
# 28 25
# estimated delay is 627_28_26
# 28 26
# estimated delay is -771_28_27
# 28 27
# estimated delay is 0_28_28
# 28 28
# estimated delay is 93_28_29
# 28 29
# estimated delay is -272_29_0
# 29 0
# estimated delay is -652_29_1
# 29 1
# estimated delay is -456_29_2
# 29 2
# estimated delay is -578_29_3
# 29 3
# estimated delay is -771_29_4
# 29 4
# estimated delay is -399_29_5
# 29 5
# estimated delay is -864_29_6
# 29 6
# estimated delay is -418_29_7
# 29 7
# estimated delay is 179_29_8
# 29 8
# estimated delay is -124_29_9
# 29 9
# estimated delay is -851_29_10
# 29 10
# estimated delay is -478_29_11
# 29 11
# estimated delay is -295_29_12
# 29 12
# estimated delay is -599_29_13
# 29 13
# estimated delay is -95_29_14
# 29 14
# estimated delay is -631_29_15
# 29 15
# estimated delay is -453_29_16
# 29 16
# estimated delay is 221_29_17
# 29 17
# estimated delay is -628_29_18
# 29 18
# estimated delay is -886_29_19
# 29 19
# estimated delay is -329_29_20
# 29 20
# estimated delay is -446_29_21
# 29 21
# estimated delay is 43_29_22
# 29 22
# estimated delay is -599_29_23
# 29 23
# estimated delay is -259_29_24
# 29 24
# estimated delay is 781_29_25
# 29 25
# estimated delay is 370_29_26
# 29 26
# estimated delay is -128_29_27
# 29 27
# estimated delay is -93_29_28
# 29 28
# estimated delay is 0_29_29
# 29 29

# %%
#エクセルファイルの変換を目指して
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
file_name = 'B39 restraint R2'
file = pd.ExcelFile(file_name+'.xls')
#all_df = pd.DataFrame()
time_file = open(file_name+'_time_data.csv', 'w')


sheet_df = file.parse(file.sheet_names, header=None)
all_df = pd.DataFrame()

sheet_names = file.sheet_names
for j, name in enumerate(sheet_names):
    sheet_df[j] = file.parse(name)
    
for i, name in enumerate(sheet_names):
    sheet_df[i] = file.parse(name)
    end_number = (np.where(sheet_df[i]['INFORMATION']=="CHANNEL")[0][1])
    sig1 = (sheet_df[i]['INFORMATION'][21:end_number-2])
    sig1 = sig1 - sig1.mean()

    for j in range(0, 30):
        end_number = (np.where(sheet_df[j]['INFORMATION']=="CHANNEL")[0][1])
        sig2 = (sheet_df[j]['INFORMATION'][21:end_number-2])
        sig2 = sig2 - sig2.mean()
        corr = np.correlate(sig1, sig2, "full")
        estimated_delay = corr.argmax() - (len(sig1) - 1)
        print("estimated delay is " + str(estimated_delay)+ "_" + str(i) +"_"+ str(j))

        plt.figure(figsize=(6, 4), dpi=30)
        plt.subplots_adjust(wspace=0.4, hspace=0.6)
        plt.subplot(4, 1, 1)
        plt.ylabel("sig"+str(i))
        plt.plot(sig1)
        
        plt.subplot(4, 1, 2)
        plt.ylabel("sig"+str(j))
        plt.plot(sig2, color="g")

        plt.subplot(4, 1, 3)
        plt.ylabel("fit")
        plt.plot(np.arange(len(sig1)), sig1)
        plt.plot(np.arange(len(sig2)) + estimated_delay, sig2 )
        plt.xlim([0, len(sig1)])

        plt.subplot(4, 1, 4)
        plt.ylabel("corr")
        plt.plot(np.arange(len(corr)) - len(sig2) + 1, corr, color="r")
        plt.xlim([0, len(sig1)])
        #plt.show()
        print(i,j)
        plt.plot()
        #plt.savefig("./image2/"+ str(i) +"_"+ str(j) +".png")
        

file.close()
time_file.close()
#print(all_df)

#import xlrd
#file = xlrd.open_workbook('B39 restraint R2.xls')
#print(file.nsheets)

#all_df.to_csv("otamesi.csv", header=False, index=False)

# %%
#エクセルファイルの変換を目指して(最大値の導出)
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
file_name = 'B39 restraint R2'
file = pd.ExcelFile(file_name+'.xls')
#all_df = pd.DataFrame()
time_file = open(file_name+'_time_data.csv', 'w')


sheet_df = file.parse(file.sheet_names, header=None)
all_df = pd.DataFrame()

sheet_names = file.sheet_names
for j, name in enumerate(sheet_names):
    sheet_df[j] = file.parse(name)
J=j
print(J)
print(len(sheet_names))
    
for i, name in enumerate(sheet_names):
    sheet_df[i] = file.parse(name)
    end_number = (np.where(sheet_df[i]['INFORMATION']=="CHANNEL")[0][1])
    sig1 = (sheet_df[i]['INFORMATION'][21:end_number-2])
    sig1 = sig1 - sig1.mean()

    for j in range(i+1, 30):
        end_number = (np.where(sheet_df[j]['INFORMATION']=="CHANNEL")[0][1])
        sig2 = (sheet_df[j]['INFORMATION'][21:end_number-2])
        sig2 = sig2 - sig2.mean()
        corr = np.correlate(sig1, sig2)#, "full")
        print(np.max(corr))
        print(np.argmax(corr))
        #print(corr.dtype)
        #a_float = corr.astype(np.float32)
        #print(a_float)
        #a=np.amax(corr)
        #print(type(a))
        #print(np.max(a))
        #print(a_float.max(axis=0))
        #print(np.arange(len(corr)) - len(sig2) + 1)


file.close()
time_file.close()
#print(all_df)

#import xlrd
#file = xlrd.open_workbook('B39 restraint R2.xls')
#print(file.nsheets)

#all_df.to_csv("otamesi.csv", header=False, index=False)
# Out:
# 29
# 30
# 30.643688907836182
# 89
# 49.76631359301486
# 27
# 26.027854097480883
# 59
# 20.60537222217791
# 119
# 8.42587197496887
# 0
# 28.716862082982708
# 266
# 30.606666441991738
# 78
# 55.06327926296151
# 355
# 28.678840754635416
# 481
# 15.046191746929178
# 75
# 47.56275851938326
# 36
# 40.19165943879421
# 113
# 26.759708365704686
# 187
# 22.842521638377455
# 68
# 14.124233495729833
# 76
# 33.62026473901978
# 251
# 35.107080209809425
# 129
# 17.12813553378189
# 13
# 28.073914456234917
# 160
# 43.374096487012146
# 27
# 37.36477613402164
# 206
# 24.84395050145023
# 593
# 20.235467478268063
# 17
# 5.695928737968055
# 42
# 44.55021098257482
# 569
# 25.22453895092369
# 875
# 30.14860112415487
# 1
# 46.78426663541315
# 71
# 53.88154957214704
# 272
# 9.828001829851027
# 43
# 30.51580275298584
# 294
# 19.44273225273632
# 248
# 19.991372423619882
# 112
# 20.537403170111965
# 227
# 26.993752876148513
# 124
# 48.59070170874035
# 363
# 46.063277405531345
# 143
# 4.474718220279548
# 0
# 43.495892845592024
# 84
# 36.85788717616439
# 578
# 26.757499840765806
# 440
# -3.7990197220303163
# 12
# 25.0900473188112
# 0
# 22.851449866406156
# 386
# 36.55901146912195
# 31
# 52.898089251375815
# 75
# 39.64971484743096
# 236
# 39.38690329460062
# 194
# 37.87354494766079
# 483
# 21.454531583551343
# 529
# 25.277596016656386
# 95
# 16.90324181753792
# 254
# 35.425710788192724
# 558
# 23.409612287636318
# 789
# 33.80726309814592
# 126
# 28.3347323061991
# 38
# 37.414069228830066
# 395
# 37.44741608603025
# 229
# 29.855388483584505
# 45
# 18.436425544267557
# 49
# 35.15325563475914
# 375
# 41.303234262580794
# 139
# 81.86983658696325
# 545
# 49.38684449529376
# 663
# 34.912175667586574
# 44
# 69.10794366229224
# 105
# 55.64907029593786
# 560
# 45.58658298352453
# 58
# 20.705332302558975
# 34
# 63.94276701438863
# 113
# 26.385149252600968
# 329
# 60.11961211304883
# 102
# 63.05973808062553
# 17
# 71.22619129150485
# 70
# 50.82641946125503
# 130
# 58.072521018567286
# 322
# 25.252542001306416
# 158
# 36.477717916984695
# 30
# 18.772940407496854
# 23
# 60.963917127274286
# 555
# 24.130988759737548
# 82
# 39.999186534296015
# 327
# 33.17193868312182
# 3
# 60.115779314860006
# 456
# -2.684810416680265
# 25
# 29.376246666002746
# 74
# 0.535200008287178
# 26
# 20.5264000944134
# 58
# 38.87244348136109
# 1090
# 29.81810497576176
# 245
# 14.3365098542975
# 290
# 36.56633015559653
# 2
# 34.29633534867437
# 196
# 38.54997908325691
# 1083
# 23.12445450285017
# 127
# 21.74051439374136
# 50
# 30.03506497948143
# 21
# 49.92810865006721
# 132
# 37.411457530319
# 0
# 8.570646140905557
# 8
# 10.863465287990612
# 106
# 42.563149476218356
# 18
# 23.619744095782163
# 369
# 18.363778050796178
# 136
# 11.452297819957103
# 85
# 39.4159549464103
# 495
# 25.760163497355148
# 1105
# 20.76932975704771
# 106
# 34.9201399626054
# 121
# 46.50581931860117
# 578
# 31.24258818034873
# 112
# 9.350129001612821
# 0
# 14.037217124485213
# 11
# 35.67868977632684
# 747
# 25.44860644744472
# 794
# 15.428570386322473
# 172
# 16.221044096430035
# 52
# 26.079347191495028
# 763
# 28.116875877251893
# 172
# 16.38036867048314
# 318
# 12.748271343541909
# 15
# 27.62005125278272
# 0
# 42.90352812660274
# 262
# 21.56197490752789
# 147
# 16.998693644751853
# 6
# 6.544801118365666
# 100
# 36.174291036096186
# 82
# 15.390818235097125
# 556
# 18.272783239659397
# 90
# 8.827610943075957
# 105
# 24.89750335386575
# 836
# 28.212662823465
# 1142
# 18.030724912059124
# 300
# 23.88642873996827
# 94
# 32.240342535226176
# 771
# 17.414905251431676
# 102
# 12.901631382349294
# 103
# 38.2824509398123
# 574
# 36.16639236209052
# 15
# 14.704254479188917
# 57
# 27.09086705688915
# 89
# 52.541081777279004
# 501
# 35.7324167807361
# 210
# 27.983519882085897
# 70
# 31.89010866363813
# 114
# 25.043300499443415
# 223
# 49.51897717062811
# 18
# 35.75926576814653
# 9
# 40.45950590580301
# 137
# 16.44663973684122
# 81
# 36.73472923471356
# 112
# 38.40607638498956
# 294
# 14.276140279510718
# 35
# 12.534838239577896
# 23
# 35.379204712568395
# 419
# 24.342081178437933
# 621
# 21.413827086824092
# 118
# 13.862272173182845
# 47
# 37.866407307972544
# 399
# 17.87376443217148
# 140
# 36.93003772120899
# 1152
# 28.01345625714326
# 504
# 20.862481092325474
# 163
# 12.174498157966907
# 39
# 29.21882719384522
# 457
# 22.932497385486183
# 153
# 19.24490080856101
# 328
# 14.827648313933608
# 104
# -3.5582034276888006
# 0
# 30.748353684713695
# 47
# 17.464170154564343
# 27
# 5.7306321638682896
# 0
# 19.989275186578926
# 51
# 15.120659988592136
# 18
# 23.338319025593673
# 880
# 20.29581560509727
# 152
# 7.143452511406865
# 101
# 31.850384029826376
# 760
# 16.829863799418696
# 682
# 24.29627053309521
# 365
# 31.906461346834718
# 323
# 22.84296463945589
# 359
# 41.025082667017664
# 926
# 30.872226558413743
# 359
# 25.670062369236227
# 8
# -13.858624117415342
# 20
# 41.49306961112542
# 699
# 19.52093470479877
# 775
# 11.540194121035126
# 81
# 25.62311897371507
# 71
# 21.178137621952324
# 112
# 30.841155611984014
# 372
# 21.08443302716568
# 17
# 40.5184996019584
# 120
# -23.480145509580034
# 0
# 28.34592751636686
# 72
# 23.870621797445246
# 739
# 11.353943631025414
# 28
# -5.752754094952598
# 16
# 22.027856948608065
# 128
# 16.91634495479537
# 824
# 24.10981108236708
# 25
# 28.123162245093706
# 192
# 28.95368293871592
# 418
# 40.88175850624822
# 117
# 39.166736360342334
# 42
# 65.62134944506424
# 338
# 25.342298395153733
# 76
# 20.49236971002428
# 66
# 31.324499194421637
# 114
# 51.34528875287244
# 246
# 39.332234958781406
# 423
# 78.23101303381704
# 256
# 67.90043506409224
# 449
# 74.46317358175732
# 84
# 52.28435085717268
# 228
# 37.55813289401302
# 1048
# 25.85826866499653
# 133
# 48.55885495520088
# 412
# 25.60769267870853
# 292
# 38.82574778983558
# 88
# 29.98428971312594
# 105
# 37.25133117471234
# 136
# 39.41873045156421
# 629
# 54.42362090792325
# 132
# 22.801288615442807
# 211
# 29.407017956611284
# 480
# 41.57301947804106
# 126
# 21.639893991552963
# 162
# 27.073788021376934
# 605
# 41.314943237341794
# 678
# 21.523557039944606
# 700
# 58.452335767536994
# 416
# 49.789619859056224
# 725
# 34.81614418828823
# 999
# 31.531250066487008
# 505
# 31.63545465958191
# 1068
# 19.03053526061171
# 156
# 27.624677784363094
# 693
# 19.00417265656966
# 485
# 35.78294349129277
# 65
# 10.86085834387979
# 2
# 27.404859550225893
# 236
# 29.424524271254185
# 860
# 35.122119889671126
# 559
# 21.771437699326242
# 172
# 25.754240101031833
# 468
# 32.70731279594488
# 252
# 8.903721414461536
# 7
# 30.320681992277247
# 202
# 9.328457167965986
# 385
# 28.15887073406801
# 62
# 24.368488634947504
# 117
# 50.83968908450988
# 143
# 14.255721273084538
# 195
# 14.568013137235916
# 293
# 19.735036655184242
# 501
# 13.341254011690568
# 213
# 12.232672814313512
# 21
# 43.16698540080348
# 772
# 19.823246401789188
# 391
# 21.121505058837624
# 115
# 7.89531857824982
# 57
# 23.762261798219956
# 241
# 49.60123005059339
# 186
# 34.03972069651745
# 34
# 20.558437927567873
# 277
# 20.849728166685484
# 14
# 22.480767962759906
# 66
# 64.87919905095308
# 213
# 46.763702232730026
# 84
# 32.88270090830793
# 38
# 41.643624028676456
# 23
# 30.486594626958922
# 229
# 29.88613972418883
# 364
# 19.066288981441637
# 46
# 2.8388765003973515
# 4
# 38.16974718951848
# 639
# 32.89295682460268
# 953
# 34.25245300629012
# 442
# 35.914686725639214
# 19
# 58.918604447617994
# 478
# 40.75705328692633
# 128
# 31.929834685159072
# 198
# 56.35901208516999
# 556
# 27.774493710270445
# 655
# 81.26670931665993
# 451
# 52.787607297646794
# 148
# 53.70435045001113
# 800
# 43.93950138551658
# 373
# 41.587762115626525
# 273
# 30.19044346527752
# 7
# 57.27390754543422
# 651
# 19.14879071563754
# 367
# 19.49897593328994
# 0
# 23.254839258373178
# 20
# 39.28991632768165
# 110
# 46.210001785238646
# 542
# 42.5472733402061
# 173
# 18.94002639215822
# 595
# 32.28617818881561
# 999
# 29.85053404485399
# 1238
# 53.85305439861272
# 559
# 48.57376474053652
# 795
# 42.49697372631657
# 1161
# 24.42309079223298
# 1020
# 35.77446704124808
# 131
# 14.014485899849392
# 118
# 42.272324134047864
# 1017
# 16.481889272262883
# 819
# 22.03166914228315
# 8
# 24.152480043767515
# 26
# 23.805310603448604
# 57
# 33.95681117348127
# 843
# 41.699152680231116
# 122
# 16.387054320124594
# 142
# 16.387806420385125
# 90
# 16.03525652301214
# 91
# 28.110798184182645
# 130
# 21.545326769667234
# 133
# 14.84974981438539
# 226
# 21.339658030202667
# 78
# 17.770844044041798
# 487
# 19.551311768115255
# 64
# 10.513682502049189
# 230
# 29.128212900685952
# 368
# 22.358129764111855
# 843
# 22.042333989584694
# 38
# 27.065657596259403
# 65
# 21.851814132353788
# 95
# 23.72000592115769
# 100
# 34.26055183060003
# 461
# 15.941533165244394
# 52
# 42.87253369779322
# 64
# 17.76584442189939
# 57
# 34.582234728001616
# 110
# 31.205191552894146
# 391
# 33.16557451568025
# 34
# 4.02559054159576
# 46
# 36.65867956204421
# 898
# 21.060639047511216
# 1105
# 28.4164068465456
# 508
# 49.80975530790731
# 270
# 50.14982674087966
# 631
# 42.01962501647312
# 121
# 23.974162362862298
# 123
# 7.941337118688795
# 46
# 20.573306978619947
# 14
# 32.131475589086975
# 77
# 32.7086738788978
# 498
# 18.31656930730284
# 229
# 17.4359250300992
# 65
# 26.743101514907917
# 374
# 22.964926405393292
# 1226
# 15.459784563127288
# 419
# 37.387746983669174
# 360
# 46.6692805136124
# 453
# 90.54443000220095
# 186
# 69.94057586557375
# 163
# 47.2469558918225
# 186
# 64.21999146518014
# 4
# 50.6614387589336
# 456
# 58.10970647913961
# 98
# 37.25666055531968
# 342
# 41.16602624405735
# 627
# 32.534415240829205
# 148
# 33.26231828629492
# 216
# 35.478100463785694
# 0
# 46.31678603903393
# 258
# 36.58090136811058
# 37
# 32.4329891910447
# 10
# 64.93846981832606
# 232
# 30.455363348338523
# 675
# 14.792015685134349
# 13
# 7.503999594989462
# 42
# 50.33815018987936
# 490
# 36.48483424410871
# 868
# 30.316362369955367
# 119
# 28.80690228350167
# 68
# 67.77163923475456
# 390
# 33.41242342544249
# 28
# 24.360758480994118
# 68
# 31.430006227761957
# 692
# 41.616815719354285
# 51
# 22.689295370759243
# 129
# 50.140943844411986
# 1044
# 32.18124147683899
# 1292
# 41.31101147846988
# 622
# 37.57854281094805
# 288
# 47.00930685343019
# 649
# 29.508022476236576
# 103
# 23.51272552963886
# 562
# 21.844121892642733
# 13
# 4.067188370391672
# 8
# 23.589129875057726
# 162
# 17.83658114819875
# 755
# 24.519554534087668
# 62
# 22.444707825256774
# 131
# 38.19409742650187
# 329
# 32.885194620883574
# 1121
# 35.183030535998796
# 302
# 10.903153480619222
# 64
# 52.283883056176116
# 1222
# 33.0273655349568
# 1224
# 26.788571414595438
# 806
# 62.287590956683665
# 476
# 50.80154305392701
# 446
# 32.7144316497321
# 464
# 12.727822604281918
# 349
# 13.598013894541154
# 53
# 17.730310052248257
# 329
# 20.383391275756733
# 83
# 35.541536358971015
# 311
# 33.53101766392086
# 135
# 2.6521274212884527
# 0
# 30.009548741855188
# 520
# 24.57049259575671
# 1073
# 17.782512738224142
# 399
# 52.387240236746926
# 55
# 48.95837355357891
# 599
# 19.904846678150957
# 851
# 14.372463773107567
# 1161
# 12.131542864941371
# 282
# 19.637301751615134
# 160
# 21.13169214476915
# 259
# 9.880584656587061
# 97
# 22.516256841565266
# 155
# 43.051181148670274
# 131
# 41.590666408533814
# 240
# 13.80080239747269
# 365
# 31.98320207584172
# 360
# 35.37371430753084
# 140
# 13.566972860621224
# 330
# 14.994346610588591
# 20
# 58.48958393935456
# 93

# %%
#自己相関を求めるために
import pandas as pd
import numpy as np
deta = pd.read_csv('otamesi.csv')
#print(deta)

#print(deta[:,0])
sig1 = deta.values[:,0]
sig2 = deta.values[:,1]
sig1_float = sig1.astype(np.float32)
print(sig1_float)


#sig1 = sig1[~np.isnan(sig1).any(axis=1)]
print(sig1[~np.isnan(sig1)])
print(sig1)
  
#np_data[0] = np_data[0] - np_data[0].mean()
#np_data[1] = np_data[1] - np_data[1].mean()
sig1 = sig1 - sig1.mean()
sig2 = sig2 - sig2.mean()

corr = np.correlate(sig1, sig2, "full")
estimated_delay = corr.argmax() - (len(sig1) - 1)
print("estimated delay is " + str(estimated_delay))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-12016465892c> in <module>()
#       8 sig1 = deta.values[:,0]
#       9 sig2 = deta.values[:,1]
# ---> 10 sig1_float = sig1.astype(np.float32)
#      11 print(sig1_float)
#      12
#
# ValueError: could not convert string to float: 'START'

# %%
#時間データから自己相関を求めるために
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import make_axes_locatable
from pylab import *
with open('/yuni/txt-data/restraint/B39 Rd.pickle', mode='rb') as fp:
    df = pickle.load(fp)


time_file = open(file_name+'_time_data.csv', 'r')

starttime = time_file[0][0]
endtime = time_file[0][1]
start = int(starttime/0.00004)
end = int(endtime/0.00004)
datatime = []
#print(df[start:end])
#specdatab = np.array(df[start:end])
for i in range(len(df[start:end])):
#    print(i)
    datatime.append([(starttime+(i*0.00004))])
    
plt.figure(figsize=(10,4))
plt.subplots_adjust(wspace=0.0, hspace=-0.4)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-87468ded0b90> in <module>()
#       5 from mpl_toolkits.axes_grid1 import make_axes_locatable
#       6 from pylab import *
# ----> 7 with open('~/yuni/txt-data/restraint/B39 Rd.pickle', mode='rb') as fp:
#       8     df = pickle.load(fp)
#       9
#
# FileNotFoundError: [Errno 2] No such file or directory: '~/yuni/txt-data/restraint/B39 Rd.pickle'

# %%
import pandas as pd
import numpy as np
import sys
import os.path


#file_name = sys.argv[1]
file_name = "B39 restraint R2.xls"                                                                                                                                                                                                           

#前後のとる範囲(s)                                                                                                                                                                                                                            
ds = 0.5

name, ext = os.path.splitext(file_name)
file = pd.ExcelFile(file_name)
time_file = open(name+'_ripple_data.csv', 'w')



sheet_df = file.parse(file.sheet_names, header=None)
all_df = pd.DataFrame()

sheet_names = file.sheet_names
for i, sheet_name in enumerate(sheet_names):
    sheet_df[i] = file.parse(sheet_name)
    start_time = sheet_df[i]['Unnamed: 1'][(np.where(sheet_df[i]['INFORMATION']=="START")[0][0])]
    if sheet_df[i]['Unnamed: 1'][(np.where(sheet_df[i]['INFORMATION']=="START")[0][0])-1] == 25000 :
        end_time = (np.where(sheet_df[i]['INFORMATION']=="START")[0][1]*4)/100000 + start_time
    else :
        end_time = (np.where(sheet_df[i]['INFORMATION']=="START")[0][1]*6)/100000 + start_time
    print("{:.6f},{:.6f}".format(start_time, end_time), file=time_file)

file.close()
time_file.close()

# %%
#エクセルファイルの変換を目指して                                                                                                                                                                                                             
import pandas as pd
import numpy as np
import sys
import os.path


#file_name = sys.argv[1]
file_name = "B39 restraint R2.xls"

#前後のとる範囲(s)                                                                                                                                                                                                                            
ds = 0.5

data = np.loadtxt(name+'_ripple_data.csv', delimiter=",")
time_file = open(name+'_time_data.csv', 'w')
label_file = open(name+'_label_data.csv', 'w')
x = np.sort(data)[::-1]


k=0

for i in range(0, len(x)-1) :     
    if( x[i-k][1] >= x[i+1-k][0] ) :  
        x[i-k][1] = x[i+1-k][1]
        x = np.delete(x, i+1-k, 0)
        k = k+1

        

print(x)
print(len(x))
# Out:
# [[772.7366  772.81224]
#  [773.30664 773.3632 ]
#  [778.65848 778.73128]
#  [786.34324 786.43928]
#  [788.17852 788.27056]
#  [788.54372 788.59196]
#  [792.17396 792.224  ]
#  [793.59408 793.67684]
#  [797.18048 797.21784]
#  [798.73324 798.78232]
#  [799.92944 799.97172]
#  [810.65268 810.7042 ]
#  [816.87416 816.93832]
#  [819.5172  819.55764]
#  [823.76844 823.814  ]
#  [826.99116 827.05032]
#  [835.1178  835.20852]
#  [835.6576  835.74236]
#  [842.03232 842.0804 ]
#  [842.08244 842.14132]
#  [847.15888 847.25756]
#  [851.08808 851.17616]
#  [851.24196 851.29084]
#  [864.78336 864.82476]
#  [867.41544 867.46932]
#  [869.14832 869.19224]
#  [869.7004  869.74332]
#  [873.07044 873.1274 ]
#  [876.11564 876.17432]
#  [892.16976 892.22232]]
# 30

# %%
start_cut = x[0][0] - ds

for i in range(0, len(x)-1) :
    if(x[i][1]+(2*ds) < x[i+1][0]) :
        print("{:.6f},{:.6f},{:.6f},{:.6f}".format(start_cut, x[i][1]+ds, x[i][0], x[i][1]), file=label_file)
        print("{:.6f},{:6f}".format(start_cut, x[i][1]+ds), file=time_file)
        start_cut = x[i+1][0]-ds
    else :
        diff = (x[i+1][0] - x[i][1])/2
        print("{:.6f},{:.6f},{:.6f},{:.6f}".format(start_cut, x[i][1]+diff, x[i][0], x[i][1]), file=label_file)
        print("{:.6f},{:.6f}".format(start_cut, x[i][1]+diff), file=time_file)
        start_cut = x[i+1][0]-diff

print("{:.6f},{:.6f},{:.6f},{:.6f}".format(start_cut, x[(len(x)-1)][1]+ds, x[(len(x)-1)][0], x[(len(x)-1)][1]), file=label_file)
print("{:.6f},{:.6f}".format(start_cut, x[(len(x)-1)][1]+ds), file=time_file)
time_file.close()
label_file.close()
print(sys.argv[1]+"----end")
