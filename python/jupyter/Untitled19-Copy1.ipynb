# %%
import random
import numpy as np
from numpy.random import *
import collections 
data = randint(0, 5, 100)

# %%
str_data = data
print(str_data)
print(type(str_data))
#print(str_data.dtype())
# Out:
# [1 0 0 4 3 0 4 1 0 3 1 2 4 2 1 0 3 4 3 4 3 1 1 4 2 0 1 3 3 4 1 0 2 0 3 3 0
#  3 4 4 3 1 1 3 1 1 4 0 2 3 0 3 3 2 1 2 2 2 1 1 4 4 1 3 1 3 3 3 1 2 3 4 2 3
#  3 4 4 3 3 4 2 2 0 2 1 4 3 0 3 0 3 4 3 0 4 0 0 0 0 3]
# <class 'numpy.ndarray'>

# %%
print(data.max())
#print(widget.data())
# Out:
# 4

# %%
def Base_10_to_n(X, n):
    X_dumy = X
    out = ''
    while X_dumy>0:
        out = str(X_dumy%n)+out
        X_dumy = int(X_dumy/n)
    return out

# %%
def count(spam, var, leng):
    found = 0
    for i in range(len(spam) - leng +1):
        if spam[i:(i+leng)] == var:
            found += 1
    return found

# %%
leng = 3

print(data.max() ** leng)
#str_data = ''.join(str_data)
#print(str_data)
list_data = str_data.astype('str')
list_data = ''.join(list_data)
print(type(list_data))
#list_data = list_data.tolist()
print(type(list_data))
#list_data = str(list_data)
list_data.replace(" ", "")
print(list_data)
# Out:
# 64
# <class 'str'>
# <class 'str'>
# 1004304103124210343431142013341020330344311311402303321222114413133312342334433422021430303430400003

# %%
np.char.count(list_data, '02')
# Out:
# array(3)

# %%
list_data = ("000000")

# %%
print(list_data.count("000"))
#clist = collections.Counter(list_data)
print(count(list_data, "000", leng))
# Out:
# 2
# 4

# %%
k = 0

for i in range(5 ** leng) : 
    pattern = Base_10_to_n(i, data.max()+1)
    print(str(pattern).zfill(leng))
    print(np.char.count(list_data, str(pattern).zfill(leng)))
    print(len(data))
    print()
    k += np.char.count(list_data, str(pattern).zfill(leng))
print(k)
# Out:
# 000
# 2
# 100
#
# 001
# 0
# 100
#
# 002
# 0
# 100
#
# 003
# 0
# 100
#
# 004
# 0
# 100
#
# 010
# 0
# 100
#
# 011
# 0
# 100
#
# 012
# 0
# 100
#
# 013
# 0
# 100
#
# 014
# 0
# 100
#
# 020
# 0
# 100
#
# 021
# 0
# 100
#
# 022
# 0
# 100
#
# 023
# 0
# 100
#
# 024
# 0
# 100
#
# 030
# 0
# 100
#
# 031
# 0
# 100
#
# 032
# 0
# 100
#
# 033
# 0
# 100
#
# 034
# 0
# 100
#
# 040
# 0
# 100
#
# 041
# 0
# 100
#
# 042
# 0
# 100
#
# 043
# 0
# 100
#
# 044
# 0
# 100
#
# 100
# 0
# 100
#
# 101
# 0
# 100
#
# 102
# 0
# 100
#
# 103
# 0
# 100
#
# 104
# 0
# 100
#
# 110
# 0
# 100
#
# 111
# 0
# 100
#
# 112
# 0
# 100
#
# 113
# 0
# 100
#
# 114
# 0
# 100
#
# 120
# 0
# 100
#
# 121
# 0
# 100
#
# 122
# 0
# 100
#
# 123
# 0
# 100
#
# 124
# 0
# 100
#
# 130
# 0
# 100
#
# 131
# 0
# 100
#
# 132
# 0
# 100
#
# 133
# 0
# 100
#
# 134
# 0
# 100
#
# 140
# 0
# 100
#
# 141
# 0
# 100
#
# 142
# 0
# 100
#
# 143
# 0
# 100
#
# 144
# 0
# 100
#
# 200
# 0
# 100
#
# 201
# 0
# 100
#
# 202
# 0
# 100
#
# 203
# 0
# 100
#
# 204
# 0
# 100
#
# 210
# 0
# 100
#
# 211
# 0
# 100
#
# 212
# 0
# 100
#
# 213
# 0
# 100
#
# 214
# 0
# 100
#
# 220
# 0
# 100
#
# 221
# 0
# 100
#
# 222
# 0
# 100
#
# 223
# 0
# 100
#
# 224
# 0
# 100
#
# 230
# 0
# 100
#
# 231
# 0
# 100
#
# 232
# 0
# 100
#
# 233
# 0
# 100
#
# 234
# 0
# 100
#
# 240
# 0
# 100
#
# 241
# 0
# 100
#
# 242
# 0
# 100
#
# 243
# 0
# 100
#
# 244
# 0
# 100
#
# 300
# 0
# 100
#
# 301
# 0
# 100
#
# 302
# 0
# 100
#
# 303
# 0
# 100
#
# 304
# 0
# 100
#
# 310
# 0
# 100
#
# 311
# 0
# 100
#
# 312
# 0
# 100
#
# 313
# 0
# 100
#
# 314
# 0
# 100
#
# 320
# 0
# 100
#
# 321
# 0
# 100
#
# 322
# 0
# 100
#
# 323
# 0
# 100
#
# 324
# 0
# 100
#
# 330
# 0
# 100
#
# 331
# 0
# 100
#
# 332
# 0
# 100
#
# 333
# 0
# 100
#
# 334
# 0
# 100
#
# 340
# 0
# 100
#
# 341
# 0
# 100
#
# 342
# 0
# 100
#
# 343
# 0
# 100
#
# 344
# 0
# 100
#
# 400
# 0
# 100
#
# 401
# 0
# 100
#
# 402
# 0
# 100
#
# 403
# 0
# 100
#
# 404
# 0
# 100
#
# 410
# 0
# 100
#
# 411
# 0
# 100
#
# 412
# 0
# 100
#
# 413
# 0
# 100
#
# 414
# 0
# 100
#
# 420
# 0
# 100
#
# 421
# 0
# 100
#
# 422
# 0
# 100
#
# 423
# 0
# 100
#
# 424
# 0
# 100
#
# 430
# 0
# 100
#
# 431
# 0
# 100
#
# 432
# 0
# 100
#
# 433
# 0
# 100
#
# 434
# 0
# 100
#
# 440
# 0
# 100
#
# 441
# 0
# 100
#
# 442
# 0
# 100
#
# 443
# 0
# 100
#
# 444
# 0
# 100
#
# 2
