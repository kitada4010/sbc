# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import pickle
import csv
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
#vine linux
f = pd.read_csv('/home/hera/nodoka/home2/nodoka/spike-data/25kHz-data/B36 Rd.csv',header=None)
f.to_pickle('/home/hera/nodoka/home2/nodoka/spike-data/25kHz-data/B36 Rd.pickle')

#mac
#f = pd.read_csv('/Volumes/NO NAME/25kHz-data/B36 Rd.csv',header=None)
#f.to_pickle('/Volumes/NO NAME/25kHz-data/B36 Rd.pickle')

#ubuntu
#f = pd.read_csv('/home/hera/nodoka/home2/nodoka/spike-data/25kHz-data/B36 Rd.csv',header=None)
#f.to_pickle('/home/nodoka/spike-data/25kHz-data/B36 Rd.pickle')

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import pickle
import csv
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
#vine linux
f = pd.read_csv('/home/hera/nodoka/home2/nodoka/spike-data/25kHz-data/B39 Rd.csv',header=None)
f.to_pickle('/home/hera/nodoka/home2/nodoka/spike-data/25kHz-data/B39 Rd.pickle')

#mac
#f = pd.read_csv('/Volumes/NO NAME/25kHz-data/B39 Rd.csv',header=None)
#f.to_pickle('/Volumes/NO NAME/25kHz-data/B39 Rd.pickle')

#ubuntu
#f = pd.read_csv('/home/hera/nodoka/home2/nodoka/spike-data/25kHz-data/B39 Rd.csv',header=None)
#f.to_pickle('/home/nodoka/spike-data/25kHz-data/B39 Rd.pickle')

# %%
import pickle
import numpy as np
import wave
from pylab import *
with open('/home/hera/nodoka/home2/nodoka/spike-data/25kHz-data/B36 Rd.pickle', mode='rb') as fp:
#with open('/home/hera/nodoka/home2/nodoka/spike-data/25kHz-data/B36 Rd.pickle', mode='rb') as fp:
#with open('/Volumes/NO NAME/25kHz-data/B36 Rd.pickle',mode='rb') as fp:
    df = pickle.load(fp)

#start = int(58.59/0.00004)
#end = int(197.47/0.00004)
#start = int(167.39/0.00004)
#end = int(272.67/0.00004)
#start = int(881.13744/0.00004)
#end = int(881.35202/0.00004)

starttime = 881.13744
endtime = 881.35202
start = int(starttime/0.00004)
end = int(endtime/0.00004)
datatime = []
#print(df[start:end])
#specdatab = np.array(df[start:end])
for i in range(len(df[start:end])):
#    print(i)
    datatime.append([(starttime+(i*0.00004))])
#print(datatime)

plt.subplot(2, 2, 1)
plt.plot(datatime,df[start:end])
del datatime

#data = df.dataframe([0], dtype='float')
#data = (pd.Series(df[start:end], dtype=np.float64))
#data = df.as_matrix(0,)#[start:end]
specdatab = np.array(df[start:end])
specdataa = specdatab.flatten()
fp.close
#print(specdataa)
N = 1024
hammingWindow = np.hamming(N)
samplingrate = 25000
length = (end - start)/samplingrate

# FFTで用いるハミング窓
hammingWindow = np.hamming(N)

# スペクトログラムを描画
plt.subplot(2, 2, 2)
pxx, freqs, bins, im = plt.specgram(specdataa, NFFT=N, Fs=samplingrate, noverlap=N-1, window=hammingWindow)
axis([0, length, 0, samplingrate / 2])
xlabel("time [second]")
plt.ylim([0,2056])
ylabel("frequency [Hz]")
plt.colorbar()

del specdataa, specdatab, pxx, freqs, bins, im, hammingWindow

plt.subplot(2, 2, 3)
starttime = 889.13744
endtime = 889.35202
datatime = []
start = int(starttime/0.00004)
end = int(endtime/0.00004)
for i in range(len(df[start:end])):
    datatime.append([(starttime+(i*0.00004))])
plt.plot(datatime,df[start:end])

#data = df.dataframe([0], dtype='float')
#data = (pd.Series(df[start:end], dtype=np.float64))
#data = df.as_matrix(0,)#[start:end]
specdatab = np.array(df[start:end])
specdataa = specdatab.flatten()
fp.close
#print(specdataa)
N = 1024
hammingWindow = np.hamming(N)
samplingrate = 25000
length = (end - start)/samplingrate

# FFTで用いるハミング窓
hammingWindow = np.hamming(N)

# スペクトログラムを描画
plt.subplot(2, 2, 4)
pxx, freqs, bins, im = plt.specgram(specdataa, NFFT=N, Fs=samplingrate, noverlap=N-1, window=hammingWindow)
axis([0, length, 0, samplingrate / 2])
xlabel("time [second]")
plt.ylim([0,2056])
ylabel("frequency [Hz]")
plt.colorbar()

plt.savefig('hikakutamesi.png',dpi=300)

del df, specdataa, specdatab, pxx, freqs, bins, im, hammingWindow

# %%
import pickle
import numpy as np
import wave
from pylab import *
with open('/home/hera/nodoka/home2/nodoka/spike-data/25kHz-data/B36 Rd.pickle', mode='rb') as fp:
#with open('/home/hera/nodoka/home2/nodoka/spike-data/25kHz-data/B36 Rd.pickle', mode='rb') as fp:
#with open('/Volumes/NO NAME/25kHz-data/B36 Rd.pickle',mode='rb') as fp:
    df = pickle.load(fp)
    
####base---------------------------------------------------------------------------------------------
starttime = 400
endtime = 800
start = int(starttime/0.00004)
end = int(endtime/0.00004)
datatime = []
#print(df[start:end])
#specdatab = np.array(df[start:end])
for i in range(len(df[start:end])):
#    print(i)
    datatime.append([(starttime+(i*0.00004))])
#print(datatime)

plt.subplot(3, 2, 1)
plt.plot(datatime,df[start:end])
del datatime

#data = df.dataframe([0], dtype='float')
#data = (pd.Series(df[start:end], dtype=np.float64))
#data = df.as_matrix(0,)#[start:end]
specdatab = np.array(df[start:end])
specdataa = specdatab.flatten()
fp.close
#print(specdataa)
N = 2048
hammingWindow = np.hamming(N)
samplingrate = 25000
length = (end - start)/samplingrate

# FFTで用いるハミング窓
hammingWindow = np.hamming(N)

# スペクトログラムを描画
plt.subplot(3, 2, 2)
pxx, freqs, bins, im = plt.specgram(specdataa, NFFT=N, Fs=samplingrate, noverlap=N/2, window=hammingWindow)
axis([0, length, 0, samplingrate / 2])
xlabel("time [second]")
plt.ylim(0,N/2)
ylabel("frequency [Hz]")
plt.colorbar()

del specdataa, specdatab, pxx, freqs, bins, im
####10min---------------------------------------------------------------------------------------------
starttime = 1700
endtime = 2100
start = int(starttime/0.00004)
end = int(endtime/0.00004)
datatime = []
#print(df[start:end])
#specdatab = np.array(df[start:end])
for i in range(len(df[start:end])):
#    print(i)
    datatime.append([(starttime+(i*0.00004))])
#print(datatime)

plt.subplot(3, 2, 3)
plt.plot(datatime,df[start:end])
del datatime

#data = df.dataframe([0], dtype='float')
#data = (pd.Series(df[start:end], dtype=np.float64))
#data = df.as_matrix(0,)#[start:end]
specdatab = np.array(df[start:end])
specdataa = specdatab.flatten()
fp.close
#print(specdataa)
N = 2048
hammingWindow = np.hamming(N)
samplingrate = 25000
length = (end - start)/samplingrate

# FFTで用いるハミング窓
hammingWindow = np.hamming(N)

# スペクトログラムを描画
plt.subplot(3, 2, 4)
pxx, freqs, bins, im = plt.specgram(specdataa, NFFT=N, Fs=samplingrate, noverlap=N/2, window=hammingWindow)
axis([0, length, 0, samplingrate / 2])
xlabel("time [second]")
plt.ylim(0,N/2)
ylabel("frequency [Hz]")
plt.colorbar()


del specdataa, specdatab, pxx, freqs, bins, im
####10min---------------------------------------------------------------------------------------------
starttime = 2750
endtime = 3150
start = int(starttime/0.00004)
end = int(endtime/0.00004)
datatime = []
#print(df[start:end])
#specdatab = np.array(df[start:end])
for i in range(len(df[start:end])):
#    print(i)
    datatime.append([(starttime+(i*0.00004))])
#print(datatime)

plt.subplot(3, 2, 5)
plt.plot(datatime,df[start:end])
del datatime

#data = df.dataframe([0], dtype='float')
#data = (pd.Series(df[start:end], dtype=np.float64))
#data = df.as_matrix(0,)#[start:end]
specdatab = np.array(df[start:end])
specdataa = specdatab.flatten()
fp.close
#print(specdataa)
N = 2048
hammingWindow = np.hamming(N)
samplingrate = 25000
length = (end - start)/samplingrate

# FFTで用いるハミング窓
hammingWindow = np.hamming(N)

# スペクトログラムを描画
plt.subplot(3, 2, 6)
pxx, freqs, bins, im = plt.specgram(specdataa, NFFT=N, Fs=samplingrate, noverlap=N/2, window=hammingWindow)
axis([0, length, 0, samplingrate / 2])
xlabel("time [second]")
plt.ylim(0,N/2)
ylabel("frequency [Hz]")
plt.colorbar()

show()

del df, specdataa, specdatab, pxx, freqs, bins, im, plt, length, samplingrate, end, start

# %%
import pickle
import numpy as np
import wave
#import matplotlib as mpl
#mpl.rcParams['agg.path.chunksize'] = 100000
from pylab import *
with open('/home/hera/nodoka/home2/nodoka/spike-data/25kHz-data/B39 Rd.pickle', mode='rb') as fp:
#with open('/home/hera/nodoka/home2/nodoka/spike-data/25kHz-data/B39 Rd.pickle', mode='rb') as fp:
#with open('/Volumes/NO NAME/25kHz-data/B39 Rd.pickle',mode='rb') as fp:
    df = pickle.load(fp)
    
####base---------------------------------------------------------------------------------------------
starttime = 400
endtime = 800
start = int(starttime/0.00004)
end = int(endtime/0.00004)
datatime = []
#print(df[start:end])
#specdatab = np.array(df[start:end])
for i in range(len(df[start:end])):
#    print(i)
    datatime.append([(starttime+(i*0.00004))])
#print(datatime)

plt.subplot(3, 2, 1)
plt.plot(datatime,df[start:end])
del datatime

#data = df.dataframe([0], dtype='float')
#data = (pd.Series(df[start:end], dtype=np.float64))
#data = df.as_matrix(0,)#[start:end]
specdatab = np.array(df[start:end])
specdataa = specdatab.flatten()
fp.close
#print(specdataa)
N = 2048
hammingWindow = np.hamming(N)
samplingrate = 25000
length = (end - start)/samplingrate

# FFTで用いるハミング窓
hammingWindow = np.hamming(N)

# スペクトログラムを描画
plt.subplot(3, 2, 2)
pxx, freqs, bins, im = plt.specgram(specdataa, NFFT=N, Fs=samplingrate, noverlap=N-1, window=hammingWindow)
axis([0, length, 0, samplingrate / 2])
xlabel("time [second]")
plt.ylim(0,N/2)
ylabel("frequency [Hz]")
plt.colorbar()

del df, specdataa, specdatab, pxx, freqs, bins, im

####10min---------------------------------------------------------------------------------------------
starttime = 1600
endtime = 2000
start = int(starttime/0.00004)
end = int(endtime/0.00004)
datatime = []
#print(df[start:end])
#specdatab = np.array(df[start:end])
for i in range(len(df[start:end])):
#    print(i)
    datatime.append([(starttime+(i*0.00004))])
#print(datatime)

plt.subplot(3, 2, 3)
plt.plot(datatime,df[start:end])
del datatime

#data = df.dataframe([0], dtype='float')
#data = (pd.Series(df[start:end], dtype=np.float64))
#data = df.as_matrix(0,)#[start:end]
specdatab = np.array(df[start:end])
specdataa = specdatab.flatten()
fp.close
#print(specdataa)
N = 2048
hammingWindow = np.hamming(N)
samplingrate = 25000
length = (end - start)/samplingrate

# FFTで用いるハミング窓
hammingWindow = np.hamming(N)

# スペクトログラムを描画
plt.subplot(3, 2, 4)
pxx, freqs, bins, im = plt.specgram(specdataa, NFFT=N, Fs=samplingrate, noverlap=N-1, window=hammingWindow)
axis([0, length, 0, samplingrate / 2])
xlabel("time [second]")
plt.ylim(0,N/2)
ylabel("frequency [Hz]")
plt.colorbar()

del df, specdataa, specdatab, pxx, freqs, bins, im

####10min---------------------------------------------------------------------------------------------
starttime = 2750
endtime = 3150
start = int(starttime/0.00004)
end = int(endtime/0.00004)
datatime = []
#print(df[start:end])
#specdatab = np.array(df[start:end])
for i in range(len(df[start:end])):
#    print(i)
    datatime.append([(starttime+(i*0.00004))])
#print(datatime)

plt.subplot(3, 2, 5)
plt.plot(datatime,df[start:end])
del datatime

#data = df.dataframe([0], dtype='float')
#data = (pd.Series(df[start:end], dtype=np.float64))
#data = df.as_matrix(0,)#[start:end]
specdatab = np.array(df[start:end])
specdataa = specdatab.flatten()
fp.close
#print(specdataa)
N = 2048
hammingWindow = np.hamming(N)
samplingrate = 25000
length = (end - start)/samplingrate

# FFTで用いるハミング窓
hammingWindow = np.hamming(N)

# スペクトログラムを描画
plt.subplot(3, 2, 6)
pxx, freqs, bins, im = plt.specgram(specdataa, NFFT=N, Fs=samplingrate, noverlap=N-1, window=hammingWindow)
axis([0, length, 0, samplingrate / 2])
xlabel("time [second]")
plt.ylim(0,N/2)
ylabel("frequency [Hz]")
plt.colorbar()

show()

del df, specdataa, specdatab, pxx, freqs, bins, im
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-2-09200a5bba9b> in <module>()
#      44 # スペクトログラムを描画
#      45 plt.subplot(3, 2, 2)
# ---> 46 pxx, freqs, bins, im = plt.specgram(specdataa, NFFT=N, Fs=samplingrate, noverlap=N-1, window=hammingWindow)
#      47 axis([0, length, 0, samplingrate / 2])
#      48 xlabel("time [second]")
#
# ~/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/matplotlib/pyplot.py in specgram(x, NFFT, Fs, Fc, detrend, window, noverlap, cmap, xextent, pad_to, sides, scale_by_freq, mode, scale, vmin, vmax, hold, data, **kwargs)
#    3540                           xextent=xextent, pad_to=pad_to, sides=sides,
#    3541                           scale_by_freq=scale_by_freq, mode=mode, scale=scale,
# -> 3542                           vmin=vmin, vmax=vmax, data=data, **kwargs)
#    3543     finally:
#    3544         ax._hold = washold
#
# ~/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1865                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1866                         RuntimeWarning, stacklevel=2)
# -> 1867             return func(ax, *args, **kwargs)
#    1868
#    1869         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# ~/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/matplotlib/axes/_axes.py in specgram(self, x, NFFT, Fs, Fc, detrend, window, noverlap, cmap, xextent, pad_to, sides, scale_by_freq, mode, scale, vmin, vmax, **kwargs)
#    7666                                        sides=sides,
#    7667                                        scale_by_freq=scale_by_freq,
# -> 7668                                        mode=mode)
#    7669
#    7670         if scale == 'linear':
#
# ~/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/matplotlib/mlab.py in specgram(x, NFFT, Fs, detrend, window, noverlap, pad_to, sides, scale_by_freq, mode)
#    1279                                       sides=sides,
#    1280                                       scale_by_freq=scale_by_freq,
# -> 1281                                       mode=mode)
#    1282
#    1283     if mode != 'complex':
#
# ~/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/matplotlib/mlab.py in _spectral_helper(x, y, NFFT, Fs, detrend_func, window, noverlap, pad_to, sides, scale_by_freq, mode)
#     707     result = detrend(result, detrend_func, axis=0)
#     708     result, windowVals = apply_window(result, window, axis=0,
# --> 709                                       return_window=True)
#     710     result = np.fft.fft(result, n=pad_to, axis=0)[:numFreqs, :]
#     711     freqs = np.fft.fftfreq(pad_to, 1/Fs)[:numFreqs]
#
# ~/.pyenv/versions/anaconda3-5.3.0/lib/python3.7/site-packages/matplotlib/mlab.py in apply_window(x, window, axis, return_window)
#     271
#     272     if return_window:
# --> 273         return windowValsRep * x, windowVals
#     274     else:
#     275         return windowValsRep * x
#
# MemoryError:
